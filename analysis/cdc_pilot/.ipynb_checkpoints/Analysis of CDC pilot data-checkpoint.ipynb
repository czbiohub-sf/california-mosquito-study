# %% [markdown]
# # Analysis of CDC pilot data

# %%
import pandas as pd
from ete3 import NCBITaxa
import os
import seaborn
import matplotlib.pyplot as plt
import math
import re
import numpy as np
from Bio import Entrez
import functions as func

# %% [markdown]
# ## 0. Description of data

# %%
data_loc = pd.DataFrame(
    data = {'report_dir':["../../data/MOS002_reports", "../../data/CMS_reports"], 
            'sample_table_csv':["../../data/MOS002_sample-table.csv", "../../data/project-mosquito_sample-table.csv"],
            'study':["CDC pilot", "CMS"]
           })

# %%
idseq_data_list = data_loc.apply(lambda x: func.read_concat_csv(x[0], x[1], x[2]), axis=1).tolist()
idseq_data_list[0] = func.add_cdc_metadata (idseq_data_list[0], "../../data/181017_MOS002_CDCpilot_MetaDataSummary.csv")
idseq_data_list[1] = func.add_extra_info (idseq_data_list[1], "../../data/sample_genus_and_species.csv")
idseq_data = pd.concat(idseq_data_list)

# %%
print("Total CDC samples "+str(len(idseq_data_list[0].sample_name.unique())))
print(idseq_data_list[0].groupby("sample_name").first().location.value_counts())
# Out:
# Total CDC samples 61
# wild-caught    31
# lab            29
# Name: location, dtype: int64

# %% [markdown]
# ## 1. Blood meal detection

# %%
bloodmeal_calls = idseq_data.groupby("sample_name").apply(func.infer_bloodmeal)

# %%
bloodmeal_calls[["MOS" in x[0] for x in list(bloodmeal_calls.index)]]
# Out:
#                               tax_id  \
# sample_name
# MOS002-01a-hom-R1   66123       8842
# MOS002-02a-hom-R1   63962       8842
# MOS002-03a-hom-R1   18177       8842
# MOS002-04a-hom-R1   46692       8842
# MOS002-05a-hom-R1   19788       8842
# MOS002-06a-W-R1     7744        8842
# MOS002-07a-W-R1     20674       8842
# MOS002-08a-W-R1     35062       8842
# MOS002-09a-W-R1     15150       8842
# MOS002-10a-W-R1     45592       8842
# MOS002-11a-hom-R1   65139     148959
# MOS002-12a-W-R1     304       148959
# MOS002-13a-hom-R1   17113       7158
# MOS002-14a-hom-R1   48401       7158
# MOS002-15a-hom-R1   19135       7182
# MOS002-16a-hom-R1   32557       9605
# MOS002-17a-hom-R1   45099       9605
# MOS002-18a-W-R1     26192       9935
# MOS002-19a-W-R1     1887        7158
# MOS002-20a-hom-R1   2820        9605
# MOS002-21a-hom-R1   69860       9605
# MOS002-22a-hom-R1   54990       9605
# MOS002-23a-hom-R1   12574      56326
# MOS002-24a-hom-R1   51837 -200008930
# MOS002-25a-hom-R1   24508      39616
# MOS002-26a-hom-R1   26718      56326
# MOS002-27a-hom-R1   37092       9605
# MOS002-28a-hom-R1   22844       9605
# MOS002-29a-hom-R1   48655       9030
# MOS002-30a-hom-R1   4570        9030
# ...                              ...
# MOS002-32a-hom-R1   60882       9030
# MOS002-33a-W-R1     745         9605
# MOS002-34a-W-R1     65439       9789
# MOS002-35a-W-R1     47604       9605
# MOS002-36a-W-R1     34081       9903
# MOS002-37a-W-R1     14612     190765
# MOS002-38a-W-R1     9243        7182
# MOS002-39a-W-R1     22107       9605
# MOS002-40a-W-R1     37852      33687
# MOS002-41a-W-R1     53934       9903
# MOS002-42a-W-R1     3615        5690
# MOS002-43a-W-R1     23750     144516
# MOS002-50a-hom-R1   10659                                            Bos
# MOS002-51a-hom-R1   57549                                            Bos
# MOS002-53a-W-R1     32411                                            Bos
# MOS002-54a-W-R1     44076                                            Bos
# MOS002-55a-W-R1     64584                                            Bos
# MOS002-56a-W-R1     1601                                             Bos
# MOS002-57a-W-R1     18816                                           Homo
# MOS002-58a-hom-R1   30038                              Parastrongyloides
# MOS002-59a-W-R1     9950                                           Aedes
# MOS002-60a-hom-R1   17512                                       Wallemia
# MOS002-61a-W-R1     36481                                       Wallemia
# MOS002-62a-Water-R1 30805                                           Homo
#
#                                    common_name  bloodfed_idseq  \
# sample_name
# MOS002-01a-hom-R1   66123                geese            True
# MOS002-02a-hom-R1   63962                geese            True
# MOS002-03a-hom-R1   18177                geese            True
# MOS002-04a-hom-R1   46692                geese            True
# MOS002-05a-hom-R1   19788                geese            True
# MOS002-06a-W-R1     7744                 geese            True
# MOS002-07a-W-R1     20674                geese            True
# MOS002-08a-W-R1     35062                geese            True
# MOS002-09a-W-R1     15150                geese            True
# MOS002-10a-W-R1     45592                geese            True
# MOS002-11a-hom-R1   65139       basidiomycetes           False
# MOS002-12a-W-R1     304         basidiomycetes           False
# MOS002-13a-hom-R1   17113            mosquitos           False
# MOS002-14a-hom-R1   48401            mosquitos           False
# MOS002-15a-hom-R1   19135            mosquitos           False
# MOS002-16a-hom-R1   32557               humans            True
# MOS002-17a-hom-R1   45099               humans            True
# MOS002-18a-W-R1     26192  even-toed ungulates            True
# MOS002-19a-W-R1     1887             mosquitos           False
# MOS002-20a-hom-R1   2820                humans            True
# MOS002-21a-hom-R1   69860               humans            True
# MOS002-22a-hom-R1   54990               humans            True
# MOS002-23a-hom-R1   12574                birds            True
# MOS002-24a-hom-R1   51837              pigeons            True
# MOS002-25a-hom-R1   24508                birds            True
# MOS002-26a-hom-R1   26718                birds            True
# MOS002-27a-hom-R1   37092               humans            True
# MOS002-28a-hom-R1   22844               humans            True
# MOS002-29a-hom-R1   48655                birds            True
# MOS002-30a-hom-R1   4570                 birds            True
# ...                                        ...             ...
# MOS002-32a-hom-R1   60882                birds            True
# MOS002-33a-W-R1     745                 humans            True
# MOS002-34a-W-R1     65439   odd-toed ungulates            True
# MOS002-35a-W-R1     47604               humans            True
# MOS002-36a-W-R1     34081                "oxen            True
# MOS002-37a-W-R1     14612            mosquitos           False
# MOS002-38a-W-R1     9243             mosquitos           False
# MOS002-39a-W-R1     22107               humans            True
# MOS002-40a-W-R1     37852      microsporidians           False
# MOS002-41a-W-R1     53934                "oxen            True
# MOS002-42a-W-R1     3615        kinetoplastids           False
# MOS002-43a-W-R1     23750      microsporidians           False
# MOS002-44a-W-R1     50772                birds            True
# MOS002-45a-W-R1     70581                birds            True
# MOS002-46a-W-R1     11247                birds            True
# MOS002-47a-W-R1     27906                birds            True
# MOS002-48a-hom-R1   29054                "oxen            True
# MOS002-49a-hom-R1   39833                "oxen            True
# MOS002-50a-hom-R1   10659                "oxen            True
# MOS002-51a-hom-R1   57549                "oxen            True
# MOS002-53a-W-R1     32411                "oxen            True
# MOS002-54a-W-R1     44076                "oxen            True
# MOS002-55a-W-R1     64584                "oxen            True
# MOS002-56a-W-R1     1601                 "oxen            True
# MOS002-57a-W-R1     18816               humans            True
# MOS002-58a-hom-R1   30038            nematodes           False
# MOS002-59a-W-R1     9950             mosquitos           False
# MOS002-60a-hom-R1   17512       basidiomycetes           False
# MOS002-61a-W-R1     36481       basidiomycetes           False
# MOS002-62a-Water-R1 30805               humans            True
#
#                            bloodfed_label     location
# sample_name
# MOS002-01a-hom-R1   66123            True          lab
# MOS002-02a-hom-R1   63962            True          lab
# MOS002-03a-hom-R1   18177            True          lab
# MOS002-04a-hom-R1   46692            True          lab
# MOS002-05a-hom-R1   19788            True          lab
# MOS002-06a-W-R1     7744             True          lab
# MOS002-07a-W-R1     20674            True          lab
# MOS002-08a-W-R1     35062            True          lab
# MOS002-09a-W-R1     15150            True          lab
# MOS002-10a-W-R1     45592            True          lab
# MOS002-11a-hom-R1   65139           False          lab
# MOS002-12a-W-R1     304             False          lab
# MOS002-13a-hom-R1   17113            True          lab
# MOS002-14a-hom-R1   48401            True          lab
# MOS002-15a-hom-R1   19135            True  wild-caught
# MOS002-16a-hom-R1   32557            True  wild-caught
# MOS002-17a-hom-R1   45099            True  wild-caught
# MOS002-18a-W-R1     26192            True          lab
# MOS002-19a-W-R1     1887             True          lab
# MOS002-20a-hom-R1   2820             True  wild-caught
# MOS002-21a-hom-R1   69860            True  wild-caught
# MOS002-22a-hom-R1   54990            True  wild-caught
# MOS002-23a-hom-R1   12574            True  wild-caught
# MOS002-24a-hom-R1   51837            True  wild-caught
# MOS002-25a-hom-R1   24508            True  wild-caught
# MOS002-26a-hom-R1   26718            True  wild-caught
# MOS002-27a-hom-R1   37092            True  wild-caught
# MOS002-28a-hom-R1   22844            True  wild-caught
# MOS002-29a-hom-R1   48655            True  wild-caught
# MOS002-30a-hom-R1   4570             True  wild-caught
# ...                                   ...          ...
# MOS002-32a-hom-R1   60882            True  wild-caught
# MOS002-33a-W-R1     745              True  wild-caught
# MOS002-34a-W-R1     65439           False  wild-caught
# MOS002-35a-W-R1     47604           False  wild-caught
# MOS002-36a-W-R1     34081           False  wild-caught
# MOS002-37a-W-R1     14612           False  wild-caught
# MOS002-38a-W-R1     9243            False  wild-caught
# MOS002-39a-W-R1     22107           False  wild-caught
# MOS002-40a-W-R1     37852           False  wild-caught
# MOS002-41a-W-R1     53934           False  wild-caught
# MOS002-42a-W-R1     3615            False  wild-caught
# MOS002-43a-W-R1     23750           False  wild-caught
# MOS002-44a-W-R1     50772           False  wild-caught
# MOS002-45a-W-R1     70581           False  wild-caught
# MOS002-46a-W-R1     11247           False  wild-caught
# MOS002-47a-W-R1     27906           False  wild-caught
# MOS002-48a-hom-R1   29054            True          lab
# MOS002-49a-hom-R1   39833            True          lab
# MOS002-50a-hom-R1   10659            True          lab
# MOS002-51a-hom-R1   57549            True          lab
# MOS002-53a-W-R1     32411           False          lab
# MOS002-54a-W-R1     44076           False          lab
# MOS002-55a-W-R1     64584           False          lab
# MOS002-56a-W-R1     1601            False          lab
# MOS002-57a-W-R1     18816           False          lab
# MOS002-58a-hom-R1   30038           False          lab
# MOS002-59a-W-R1     9950            False          lab
# MOS002-60a-hom-R1   17512           False          lab
# MOS002-61a-W-R1     36481           False          lab
# MOS002-62a-Water-R1 30805            True          NaN
#
# [61 rows x 6 columns]

# %%
bloodmeal_calls.to_csv("../../data/bloodmeal_calls.csv", header=True, index=True)

# %% [markdown]
# ## 2. Comparison of singleton mosquito vs homogenate analysis

# %%
idseq_data_list[0][(idseq_data_list[0].tax_level==1)&(idseq_data_list[0].sample_type!="water")]\
.sort_values(["NT_r"], ascending=False)\
.groupby("sample_name").apply(lambda x: x.head(5))\
.replace({'sample_type':{'aliquot of whole insect homogenate':'homogenate', 'homegenate':'homogenate'}})\
.groupby("sample_type").apply(lambda x: x["category_name"].value_counts())
# Out:
# sample_type
# homogenate   Bacteria     82
#              Eukaryota    64
#              Viruses       4
# whole        Eukaryota    81
#              Bacteria     67
#              Viruses       2
# Name: category_name, dtype: int64

# %% [markdown]
# ## 3. Comparison with CMS studies

# %%
prop_reads_df = func.calc_prop_reads(idseq_data)

# %%
prop_reads_df.to_csv("../../data/proportion_reads_kingdoms.csv")

# %%
prop_reads_plot_df = pd.melt(prop_reads_df, id_vars=['sample_name', 'location', 'sample_type', 'study'],
                             value_vars=['Archaea', 'Bacteria', 'Eukaryota', 'Viruses', 'Uncategorized'], 
                             var_name='Kingdom', value_name='Proportion of reads')
prop_reads_plot_df = prop_reads_plot_df[(~prop_reads_plot_df.sample_name.str.contains('ater')) & (prop_reads_plot_df.Kingdom!="Uncategorized")]
g = seaborn.FacetGrid(prop_reads_plot_df, col="Kingdom", col_wrap=5, legend_out=True)
g = g.map_dataframe(seaborn.boxplot, x="study", y="Proportion of reads", hue="location", orient="v",
               palette="Set3")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-31fda5483934> in <module>()
#       6 g = seaborn.FacetGrid(prop_reads_plot_df, col="Kingdom", col_wrap=5, legend_out=True)
#       7 g = g.map_dataframe(seaborn.boxplot, ax=axes, x="study", y="Proportion of reads", hue="location", orient="v",
# ----> 8                palette="Set3")
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     807
#     808             # Draw the plot
# --> 809             self._facet_plot(func, ax, args, kwargs)
#     810
#     811         # Finalize the annotations and layout
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     825
#     826         # Draw the plot
# --> 827         func(*plot_args, **plot_kwargs)
#     828
#     829         # Sort out the supporting information
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2215     kwargs.update(dict(whis=whis, notch=notch))
#    2216
# -> 2217     plotter.plot(ax, kwargs)
#    2218     return ax
#    2219
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in plot(self, ax, boxplot_kws)
#     542     def plot(self, ax, boxplot_kws):
#     543         """Make the plot."""
# --> 544         self.draw_boxplot(ax, boxplot_kws)
#     545         self.annotate_axes(ax)
#     546         if self.orient == "h":
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in draw_boxplot(self, ax, kws)
#     489                     # Add a legend for this hue level
#     490                     if not i:
# --> 491                         self.add_legend_data(ax, self.colors[j], hue_level)
#     492
#     493                     # Handle case where there is data at this level
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in add_legend_data(self, ax, color, label)
#     430                              facecolor=color,
#     431                              label=label)
# --> 432         ax.add_patch(rect)
#     433
#     434
#
# AttributeError: 'numpy.ndarray' object has no attribute 'add_patch'

# %% [markdown]
# ## 4. Viral diversity in CMS samples

# %%
viral_diversity_df = func.calc_viral_diversity(idseq_data, log=True)

# %%
plot_heatmap(viral_diversity_df, xticklabels=False, yticklabels=False)

# %%
num_viral_species_df = pd.merge(viral_diversity_df.apply(lambda x: (x>-4.9).sum(), axis=1)\
                                .to_frame(name="Number of virus species"), idseq_data[["sample_name", "study", "location"]]\
                                .groupby("sample_name").first().reset_index(), 
                                how="left", left_index=True, right_on="sample_name")\
[["sample_name", "study", "location", "Number of virus species"]]

fig, ax = plt.subplots(figsize=(12, 7))
seaborn.boxplot(ax=ax, x="study", y="Number of virus species", hue="location", orient="v", data=num_viral_species_df)
ax.legend(loc='lower left', bbox_to_anchor= (0.0, 1.01), ncol=2, 
            borderaxespad=0, frameon=False)

# %%
num_viral_species_df.sort_values(by="Number of virus species").groupby("study").tail(10).sort_values(by="sample_name")
# Out:
#                      sample_name      study     location  \
# 0              CMS-076_RNA_A_S12        CMS  wild-caught
# 3               CMS-080_RNA_A_S7        CMS  wild-caught
# 4               CMS-081_RNA_A_S8        CMS  wild-caught
# 7              CMS-086_RNA_A_S11        CMS  wild-caught
# 62      CMS_002_38a_Rb_S172_L004        CMS  wild-caught
# 95        CMS_002_53a_Rb_S7_L004        CMS  wild-caught
# 112             CMS_006_RNA_A_S1        CMS  wild-caught
# 169  CMS_088b_Dynabeads_RNA_A_S6        CMS  wild-caught
# 174               CMS_D_RNA_A_S1        CMS  wild-caught
# 178        CMS_water3_Qiagen_S26        CMS  wild-caught
# 189              MOS002-09a-W-R1  CDC pilot          lab
# 204            MOS002-24a-hom-R1  CDC pilot  wild-caught
# 209            MOS002-29a-hom-R1  CDC pilot  wild-caught
# 210            MOS002-30a-hom-R1  CDC pilot  wild-caught
# 211            MOS002-31a-hom-R1  CDC pilot  wild-caught
# 212            MOS002-32a-hom-R1  CDC pilot  wild-caught
# 215              MOS002-35a-W-R1  CDC pilot  wild-caught
# 216              MOS002-36a-W-R1  CDC pilot  wild-caught
# 225              MOS002-45a-W-R1  CDC pilot  wild-caught
# 229            MOS002-49a-hom-R1  CDC pilot          lab
#
#      Number of virus species
# 0                         12
# 3                         11
# 4                         11
# 7                         11
# 62                        10
# 95                        16
# 112                       11
# 169                       10
# 174                       10
# 178                       12
# 189                        5
# 204                        8
# 209                        7
# 210                       11
# 211                       15
# 212                       11
# 215                        5
# 216                        5
# 225                        5
# 229                        9

# %%
Entrez.email = "lucy.li@czbiohub.org"
ncbi = NCBITaxa()
virus_search_results = [Entrez.read(Entrez.esearch(db="Taxonomy", term=x, retmode="xml")) for x in viral_diversity_df.columns]
# virus_family_id = [ncbi.get_lineage(str(Entrez.read(Entrez.esearch(db="Taxonomy", term=x, retmode="xml"))['IdList'][0]))[-3] \
#                    for x in viral_diversity_df.columns]

# %%
virus_search_results
# Out:
# [DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1913571'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Acinetobacter phage AM24[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Acinetobacter phage AM24[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1560342'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Acinetobacter phage YMC13/03/R2096[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': '
All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan Mosquito Virus 5[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1608131'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan Mosquito Virus 6[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan Mosquito Virus 6[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1608133'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan Mosquito Virus 8[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan Mosquito Virus 8[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1608134'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan Mosquito Virus 9[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan Mosquito Virus 9[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1608138'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan Tick Virus 2[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan Tick Virus 2[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1746067'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan aphid virus 1[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan aphid virus 1[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1746068'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan aphid virus 2[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan aphid virus 2[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1923695'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan coneheads virus 1[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan coneheads virus 1[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1923698'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan fly virus 4[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan fly virus 4[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1923699'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan fly virus 5[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan fly virus 5[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1923715'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan insect virus 11[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan insect virus 11[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1923717'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan insect virus 13[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan insect virus 13[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1923725'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan insect virus 21[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan insect virus 21[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1923726'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan insect virus 22[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan insect virus 22[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1923730'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan insect virus 26[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan insect virus 26[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1923736'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan insect virus 33[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan insect virus 33[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1980543'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan mosquito orthophasmavirus 1[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan mosquito orthophasmavirus 1[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1980544'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wuhan mosquito orthophasmavirus 2[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wuhan mosquito orthophasmavirus 2[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1980612'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wutai Mosquito Virus[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wutai Mosquito Virus[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1980612'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wutai mosquito phasivirus[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wutai mosquito phasivirus[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['273350'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Wyeomyia orthobunyavirus[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Wyeomyia orthobunyavirus[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1884460'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Xincheng anphevirus[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Xincheng anphevirus[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1821227'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Xishuangbanna aedes flavivirus[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Xishuangbanna aedes flavivirus[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1415147'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Xylella phage Salvo[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Xylella phage Salvo[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1920137'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Xysticus cristatus iflavirus[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Xysticus cristatus iflavirus[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1819307'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Yacaaba virus[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Yacaaba virus[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1586713'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Yellowstone lake phycodnavirus 1[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Yellowstone lake phycodnavirus 1[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1735591'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Yersinia phage vB_YenP_AP10[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Yersinia phage vB_YenP_AP10[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['2053026'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Yichang virus[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Yichang virus[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['306276'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Yunnan orbivirus[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Yunnan orbivirus[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['186538'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Zaire ebolavirus[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Zaire ebolavirus[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1923779'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'Zhejiang mosquito virus 3[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'Zhejiang mosquito virus 3[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1075826'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'dsRNA virus environmental sample[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'dsRNA virus environmental sample[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['2100421'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'uncultured Caudovirales phage[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'uncultured Caudovirales phage[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['1034795'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'uncultured Herpesvirus[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'uncultured Herpesvirus[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['742825'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'uncultured circovirus[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'uncultured circovirus[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['186617'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'uncultured marine virus[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'uncultured marine virus[All Names]'}, attributes={}),
#  DictElement({'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['340016'], 'TranslationSet': [], 'TranslationStack': [DictElement({'Term': 'uncultured virus[All Names]', 'Field': 'All Names', 'Count': '1', 'Explode': 'N'}, attributes={}), 'GROUP'], 'QueryTranslation': 'uncultured virus[All Names]'}, attributes={})]

# %%
idseq_data[idseq_data.name.str.contains("Wolbachia").fillna(False)]
# Out:
#                      sample_name     tax_id  \
# 0                MOS002-12a-W-R1        953
# 1                MOS002-12a-W-R1     263437
# 2                MOS002-12a-W-R1 -100000953
# 3                MOS002-12a-W-R1     307502
# 4                MOS002-12a-W-R1     329647
# 5                MOS002-12a-W-R1     169402
# 6                MOS002-12a-W-R1        955
# 7                MOS002-12a-W-R1     246273
# 8                MOS002-12a-W-R1      80849
# 9                MOS002-12a-W-R1      77038
# 10               MOS002-12a-W-R1     244204
# 11               MOS002-12a-W-R1     424187
# 12               MOS002-12a-W-R1        956
# 13               MOS002-12a-W-R1     201175
# 14               MOS002-12a-W-R1     146720
# 15               MOS002-12a-W-R1    1075197
# 16               MOS002-12a-W-R1    1633785
# 17               MOS002-12a-W-R1    1605993
# 18               MOS002-12a-W-R1    1695167
# 19               MOS002-12a-W-R1    1695168
# 20               MOS002-12a-W-R1     215173
# 21               MOS002-12a-W-R1     125593
# 22               MOS002-12a-W-R1     180837
# 23               MOS002-12a-W-R1     282306
# 24               MOS002-12a-W-R1     374737
# 25               MOS002-12a-W-R1     368602
# 26               MOS002-12a-W-R1     116598
# 27               MOS002-12a-W-R1     749451
# 28               MOS002-12a-W-R1     500618
# 29               MOS002-12a-W-R1    1653378
# ...                          ...        ...
# 138064         CMS_042_RNA_A_S23      77038
# 138887         CMS_026_RNA_A_S18        953
# 138888         CMS_026_RNA_A_S18      77038
# 138889         CMS_026_RNA_A_S18 -100000953
# 139559          CMS_010_RNA_A_S1        953
# 139560          CMS_010_RNA_A_S1 -100000953
# 140140         CMS_027_RNA_A_S16        953
# 140141         CMS_027_RNA_A_S16        955
# 141668          CMS_053_RNA_A_S8        953
# 141669          CMS_053_RNA_A_S8        955
# 141670          CMS_053_RNA_A_S8      77038
# 142411         CMS_036_RNA_A_S20        953
# 142412         CMS_036_RNA_A_S20     307502
# 142413         CMS_036_RNA_A_S20      77038
# 142414         CMS_036_RNA_A_S20 -100000953
# 144327          CMS_011_RNA_A_S4        953
# 144328          CMS_011_RNA_A_S4        955
# 144329          CMS_011_RNA_A_S4 -100000953
# 144330          CMS_011_RNA_A_S4     169402
# 144331          CMS_011_RNA_A_S4      77038
# 145690           CMS_70_RNA_A_S4        953
# 145691           CMS_70_RNA_A_S4 -100000953
# 148581  CMS_002_25e_Rb_S144_L004        953
# 148582  CMS_002_25e_Rb_S144_L004     307502
# 148583  CMS_002_25e_Rb_S144_L004     263437
# 148584  CMS_002_25e_Rb_S144_L004 -100000953
# 149674          CMS_045_RNA_A_S2        953
# 149675          CMS_045_RNA_A_S2        955
# 150873          CMS_005_RNA_A_S3        953
# 150874          CMS_005_RNA_A_S3 -100000953
#
#                                                     name common_name  \
# 0                                              Wolbachia         NaN
# 1       Wolbachia endosymbiont of Culex quinquefasciatus         NaN
# 2          Non-species-specific reads in genus Wolbachia         NaN
# 3         Wolbachia endosymbiont of Drosophila ananassae         NaN
# 4               Wolbachia endosymbiont of Culex molestus         NaN
# 5             Wolbachia endosymbiont of Folsomia candida         NaN
# 6                                    Wolbachia pipientis         NaN
# 7            Wolbachia endosymbiont of Cimex lectularius         NaN
# 8                Wolbachia endosymbiont of Brugia malayi         NaN
# 9          Wolbachia endosymbiont of Drosophila simulans         NaN
# 10                              uncultured Wolbachia sp.         NaN
# 11              Wolbachia endosymbiont of Ixodes ricinus         NaN
# 12                                         Wolbachia sp.         NaN
# 13         Wolbachia endosymbiont of Exorista sorbillans         NaN
# 14             Wolbachia endosymbiont of Orseolia oryzae         NaN
# 15           Wolbachia endosymbiont of Eupteryx melissae         NaN
# 16         Wolbachia endosymbiont of Drosophila incompta         NaN
# 17          Wolbachia endosymbiont of Dactylopius coccus         NaN
# 18             Wolbachia endosymbiont of Mycopsylla fici         NaN
# 19          Wolbachia endosymbiont of Mycopsylla proxima         NaN
# 20              Wolbachia endosymbiont of Bemisia tabaci         NaN
# 21      Wolbachia endosymbiont of Trichogramma pretiosum         NaN
# 22         Wolbachia endosymbiont of Nasonia vitripennis         NaN
# 23      Wolbachia endosymbiont of Trichogramma ostriniae         NaN
# 24                         Candidatus Wolbachia inokumae         NaN
# 25       Wolbachia endosymbiont of Laodelphax striatella         NaN
# 26            Wolbachia endosymbiont of Diaphorina citri         NaN
# 27          Wolbachia endosymbiont of Balloniscus glaber         NaN
# 28       Wolbachia endosymbiont of Linyphia triangularis         NaN
# 29      Wolbachia endosymbiont of Phyllonorycter platani         NaN
# ...                                                  ...         ...
# 138064     Wolbachia endosymbiont of Drosophila simulans         NaN
# 138887                                         Wolbachia         NaN
# 138888     Wolbachia endosymbiont of Drosophila simulans         NaN
# 138889     Non-species-specific reads in genus Wolbachia         NaN
# 139559                                         Wolbachia         NaN
# 139560     Non-species-specific reads in genus Wolbachia         NaN
# 140140                                         Wolbachia         NaN
# 140141                               Wolbachia pipientis         NaN
# 141668                                         Wolbachia         NaN
# 141669                               Wolbachia pipientis         NaN
# 141670     Wolbachia endosymbiont of Drosophila simulans         NaN
# 142411                                         Wolbachia         NaN
# 142412    Wolbachia endosymbiont of Drosophila ananassae         NaN
# 142413     Wolbachia endosymbiont of Drosophila simulans         NaN
# 142414     Non-species-specific reads in genus Wolbachia         NaN
# 144327                                         Wolbachia         NaN
# 144328                               Wolbachia pipientis         NaN
# 144329     Non-species-specific reads in genus Wolbachia         NaN
# 144330        Wolbachia endosymbiont of Folsomia candida         NaN
# 144331     Wolbachia endosymbiont of Drosophila simulans         NaN
# 145690                                         Wolbachia         NaN
# 145691     Non-species-specific reads in genus Wolbachia         NaN
# 148581                                         Wolbachia         NaN
# 148582    Wolbachia endosymbiont of Drosophila ananassae         NaN
# 148583  Wolbachia endosymbiont of Culex quinquefasciatus         NaN
# 148584     Non-species-specific reads in genus Wolbachia         NaN
# 149674                                         Wolbachia         NaN
# 149675                               Wolbachia pipientis         NaN
# 150873                                         Wolbachia         NaN
# 150874     Non-species-specific reads in genus Wolbachia         NaN
#
#         tax_level  species_taxid  genus_taxid  family_taxid category_name  \
# 0               2           -100          953           942      Bacteria
# 1               1         263437          953           942      Bacteria
# 2               1     -100000953          953           942      Bacteria
# 3               1         307502          953           942      Bacteria
# 4               1         329647          953           942      Bacteria
# 5               1         169402          953           942      Bacteria
# 6               1            955          953           942      Bacteria
# 7               1         246273          953           942      Bacteria
# 8               1          80849          953           942      Bacteria
# 9               1          77038          953           942      Bacteria
# 10              1         244204          953           942      Bacteria
# 11              1         424187          953           942      Bacteria
# 12              1            956          953           942      Bacteria
# 13              1         201175          953           942      Bacteria
# 14              1         146720          953           942      Bacteria
# 15              1        1075197          953           942      Bacteria
# 16              1        1633785          953           942      Bacteria
# 17              1        1605993          953           942      Bacteria
# 18              1        1695167          953           942      Bacteria
# 19              1        1695168          953           942      Bacteria
# 20              1         215173          953           942      Bacteria
# 21              1         125593          953           942      Bacteria
# 22              1         180837          953           942      Bacteria
# 23              1         282306          953           942      Bacteria
# 24              1         374737          953           942      Bacteria
# 25              1         368602          953           942      Bacteria
# 26              1         116598          953           942      Bacteria
# 27              1         749451          953           942      Bacteria
# 28              1         500618          953           942      Bacteria
# 29              1        1653378          953           942      Bacteria
# ...           ...            ...          ...           ...           ...
# 138064          1          77038          953           942      Bacteria
# 138887          2           -100          953           942      Bacteria
# 138888          1          77038          953           942      Bacteria
# 138889          1     -100000953          953           942      Bacteria
# 139559          2           -100          953           942      Bacteria
# 139560          1     -100000953          953           942      Bacteria
# 140140          2           -100          953           942      Bacteria
# 140141          1            955          953           942      Bacteria
# 141668          2           -100          953           942      Bacteria
# 141669          1            955          953           942      Bacteria
# 141670          1          77038          953           942      Bacteria
# 142411          2           -100          953           942      Bacteria
# 142412          1         307502          953           942      Bacteria
# 142413          1          77038          953           942      Bacteria
# 142414          1     -100000953          953           942      Bacteria
# 144327          2           -100          953           942      Bacteria
# 144328          1            955          953           942      Bacteria
# 144329          1     -100000953          953           942      Bacteria
# 144330          1         169402          953           942      Bacteria
# 144331          1          77038          953           942      Bacteria
# 145690          2           -100          953           942      Bacteria
# 145691          1     -100000953          953           942      Bacteria
# 148581          2           -100          953           942      Bacteria
# 148582          1         307502          953           942      Bacteria
# 148583          1         263437          953           942      Bacteria
# 148584          1     -100000953          953           942      Bacteria
# 149674          2           -100          953           942      Bacteria
# 149675          1            955          953           942      Bacteria
# 150873          2           -100          953           942      Bacteria
# 150874          1     -100000953          953           942      Bacteria
#
#         is_phage       ...        nucleotide_type     location  host_genome  \
# 0              0       ...                    RNA          lab     Mosquito
# 1              0       ...                    RNA          lab     Mosquito
# 2              0       ...                    RNA          lab     Mosquito
# 3              0       ...                    RNA          lab     Mosquito
# 4              0       ...                    RNA          lab     Mosquito
# 5              0       ...                    RNA          lab     Mosquito
# 6              0       ...                    RNA          lab     Mosquito
# 7              0       ...                    RNA          lab     Mosquito
# 8              0       ...                    RNA          lab     Mosquito
# 9              0       ...                    RNA          lab     Mosquito
# 10             0       ...                    RNA          lab     Mosquito
# 11             0       ...                    RNA          lab     Mosquito
# 12             0       ...                    RNA          lab     Mosquito
# 13             0       ...                    RNA          lab     Mosquito
# 14             0       ...                    RNA          lab     Mosquito
# 15             0       ...                    RNA          lab     Mosquito
# 16             0       ...                    RNA          lab     Mosquito
# 17             0       ...                    RNA          lab     Mosquito
# 18             0       ...                    RNA          lab     Mosquito
# 19             0       ...                    RNA          lab     Mosquito
# 20             0       ...                    RNA          lab     Mosquito
# 21             0       ...                    RNA          lab     Mosquito
# 22             0       ...                    RNA          lab     Mosquito
# 23             0       ...                    RNA          lab     Mosquito
# 24             0       ...                    RNA          lab     Mosquito
# 25             0       ...                    RNA          lab     Mosquito
# 26             0       ...                    RNA          lab     Mosquito
# 27             0       ...                    RNA          lab     Mosquito
# 28             0       ...                    RNA          lab     Mosquito
# 29             0       ...                    RNA          lab     Mosquito
# ...          ...       ...                    ...          ...          ...
# 138064         0       ...                    RNA  wild-caught     Mosquito
# 138887         0       ...                    RNA  wild-caught     Mosquito
# 138888         0       ...                    RNA  wild-caught     Mosquito
# 138889         0       ...                    RNA  wild-caught     Mosquito
# 139559         0       ...                    RNA  wild-caught     Mosquito
# 139560         0       ...                    RNA  wild-caught     Mosquito
# 140140         0       ...                    RNA  wild-caught     Mosquito
# 140141         0       ...                    RNA  wild-caught     Mosquito
# 141668         0       ...                    RNA  wild-caught     Mosquito
# 141669         0       ...                    RNA  wild-caught     Mosquito
# 141670         0       ...                    RNA  wild-caught     Mosquito
# 142411         0       ...                    RNA  wild-caught     Mosquito
# 142412         0       ...                    RNA  wild-caught     Mosquito
# 142413         0       ...                    RNA  wild-caught     Mosquito
# 142414         0       ...                    RNA  wild-caught     Mosquito
# 144327         0       ...                    RNA  wild-caught     Mosquito
# 144328         0       ...                    RNA  wild-caught     Mosquito
# 144329         0       ...                    RNA  wild-caught     Mosquito
# 144330         0       ...                    RNA  wild-caught     Mosquito
# 144331         0       ...                    RNA  wild-caught     Mosquito
# 145690         0       ...                    NaN  wild-caught     Mosquito
# 145691         0       ...                    NaN  wild-caught     Mosquito
# 148581         0       ...                    RNA  wild-caught     Mosquito
# 148582         0       ...                    RNA  wild-caught     Mosquito
# 148583         0       ...                    RNA  wild-caught     Mosquito
# 148584         0       ...                    RNA  wild-caught     Mosquito
# 149674         0       ...                    RNA  wild-caught     Mosquito
# 149675         0       ...                    RNA  wild-caught     Mosquito
# 150873         0       ...                    RNA  wild-caught     Mosquito
# 150874         0       ...                    RNA  wild-caught     Mosquito
#
#                                                     notes  sample_diagnosis  \
# 0       - id_method : freeze\n- genus_species: Culex q...               NaN
# 1       - id_method : freeze\n- genus_species: Culex q...               NaN
# 2       - id_method : freeze\n- genus_species: Culex q...               NaN
# 3       - id_method : freeze\n- genus_species: Culex q...               NaN
# 4       - id_method : freeze\n- genus_species: Culex q...               NaN
# 5       - id_method : freeze\n- genus_species: Culex q...               NaN
# 6       - id_method : freeze\n- genus_species: Culex q...               NaN
# 7       - id_method : freeze\n- genus_species: Culex q...               NaN
# 8       - id_method : freeze\n- genus_species: Culex q...               NaN
# 9       - id_method : freeze\n- genus_species: Culex q...               NaN
# 10      - id_method : freeze\n- genus_species: Culex q...               NaN
# 11      - id_method : freeze\n- genus_species: Culex q...               NaN
# 12      - id_method : freeze\n- genus_species: Culex q...               NaN
# 13      - id_method : freeze\n- genus_species: Culex q...               NaN
# 14      - id_method : freeze\n- genus_species: Culex q...               NaN
# 15      - id_method : freeze\n- genus_species: Culex q...               NaN
# 16      - id_method : freeze\n- genus_species: Culex q...               NaN
# 17      - id_method : freeze\n- genus_species: Culex q...               NaN
# 18      - id_method : freeze\n- genus_species: Culex q...               NaN
# 19      - id_method : freeze\n- genus_species: Culex q...               NaN
# 20      - id_method : freeze\n- genus_species: Culex q...               NaN
# 21      - id_method : freeze\n- genus_species: Culex q...               NaN
# 22      - id_method : freeze\n- genus_species: Culex q...               NaN
# 23      - id_method : freeze\n- genus_species: Culex q...               NaN
# 24      - id_method : freeze\n- genus_species: Culex q...               NaN
# 25      - id_method : freeze\n- genus_species: Culex q...               NaN
# 26      - id_method : freeze\n- genus_species: Culex q...               NaN
# 27      - id_method : freeze\n- genus_species: Culex q...               NaN
# 28      - id_method : freeze\n- genus_species: Culex q...               NaN
# 29      - id_method : freeze\n- genus_species: Culex q...               NaN
# ...                                                   ...               ...
# 138064              Culex tarsalis_08/25/17_Skywest Golf_               NaN
# 138887  Culex tarsalis_09/19/17_Park Meadow Pond (Frem...               NaN
# 138888  Culex tarsalis_09/19/17_Park Meadow Pond (Frem...               NaN
# 138889  Culex tarsalis_09/19/17_Park Meadow Pond (Frem...               NaN
# 139559         Culex_erythrothorax_9/19/17_Coyotes Hills_               NaN
# 139560         Culex_erythrothorax_9/19/17_Coyotes Hills_               NaN
# 140140  Culex tarsalis_09/12/17_McLaughlin Park (Berke...               NaN
# 140141  Culex tarsalis_09/12/17_McLaughlin Park (Berke...               NaN
# 141668       Culex_erythrothorax_10/7/2017_Coyotes Hills_               NaN
# 141669       Culex_erythrothorax_10/7/2017_Coyotes Hills_               NaN
# 141670       Culex_erythrothorax_10/7/2017_Coyotes Hills_               NaN
# 142411             Culex tarsalis_09/11/17_Coyotes Hills_               NaN
# 142412             Culex tarsalis_09/11/17_Coyotes Hills_               NaN
# 142413             Culex tarsalis_09/11/17_Coyotes Hills_               NaN
# 142414             Culex tarsalis_09/11/17_Coyotes Hills_               NaN
# 144327        Culex erythrothorax_09/19/17_Coyotes Hills_               NaN
# 144328        Culex erythrothorax_09/19/17_Coyotes Hills_               NaN
# 144329        Culex erythrothorax_09/19/17_Coyotes Hills_               NaN
# 144330        Culex erythrothorax_09/19/17_Coyotes Hills_               NaN
# 144331        Culex erythrothorax_09/19/17_Coyotes Hills_               NaN
# 145690                                                NaN               NaN
# 145691                                                NaN               NaN
# 148581  - id_method : TEA\n- genus_species: Ae. Aegypt...               NaN
# 148582  - id_method : TEA\n- genus_species: Ae. Aegypt...               NaN
# 148583  - id_method : TEA\n- genus_species: Ae. Aegypt...               NaN
# 148584  - id_method : TEA\n- genus_species: Ae. Aegypt...               NaN
# 149674               Culex_tarsalis_8/3/17_Coyotes Hills_               NaN
# 149675               Culex_tarsalis_8/3/17_Coyotes Hills_               NaN
# 150873  Culex incidens_09/29/17_Officers Club_Environm...               NaN
# 150874  Culex incidens_09/29/17_Officers Club_Environm...               NaN
#
#             study  sample_type        mosquito_species  n_mosquito  \
# 0       CDC pilot        whole  Culex quinquefasciatus        11.0
# 1       CDC pilot        whole  Culex quinquefasciatus        11.0
# 2       CDC pilot        whole  Culex quinquefasciatus        11.0
# 3       CDC pilot        whole  Culex quinquefasciatus        11.0
# 4       CDC pilot        whole  Culex quinquefasciatus        11.0
# 5       CDC pilot        whole  Culex quinquefasciatus        11.0
# 6       CDC pilot        whole  Culex quinquefasciatus        11.0
# 7       CDC pilot        whole  Culex quinquefasciatus        11.0
# 8       CDC pilot        whole  Culex quinquefasciatus        11.0
# 9       CDC pilot        whole  Culex quinquefasciatus        11.0
# 10      CDC pilot        whole  Culex quinquefasciatus        11.0
# 11      CDC pilot        whole  Culex quinquefasciatus        11.0
# 12      CDC pilot        whole  Culex quinquefasciatus        11.0
# 13      CDC pilot        whole  Culex quinquefasciatus        11.0
# 14      CDC pilot        whole  Culex quinquefasciatus        11.0
# 15      CDC pilot        whole  Culex quinquefasciatus        11.0
# 16      CDC pilot        whole  Culex quinquefasciatus        11.0
# 17      CDC pilot        whole  Culex quinquefasciatus        11.0
# 18      CDC pilot        whole  Culex quinquefasciatus        11.0
# 19      CDC pilot        whole  Culex quinquefasciatus        11.0
# 20      CDC pilot        whole  Culex quinquefasciatus        11.0
# 21      CDC pilot        whole  Culex quinquefasciatus        11.0
# 22      CDC pilot        whole  Culex quinquefasciatus        11.0
# 23      CDC pilot        whole  Culex quinquefasciatus        11.0
# 24      CDC pilot        whole  Culex quinquefasciatus        11.0
# 25      CDC pilot        whole  Culex quinquefasciatus        11.0
# 26      CDC pilot        whole  Culex quinquefasciatus        11.0
# 27      CDC pilot        whole  Culex quinquefasciatus        11.0
# 28      CDC pilot        whole  Culex quinquefasciatus        11.0
# 29      CDC pilot        whole  Culex quinquefasciatus        11.0
# ...           ...          ...                     ...         ...
# 138064        CMS        whole                     NaN         1.0
# 138887        CMS        whole                     NaN         1.0
# 138888        CMS        whole                     NaN         1.0
# 138889        CMS        whole                     NaN         1.0
# 139559        CMS        whole                     NaN         1.0
# 139560        CMS        whole                     NaN         1.0
# 140140        CMS        whole                     NaN         1.0
# 140141        CMS        whole                     NaN         1.0
# 141668        CMS        whole                     NaN         1.0
# 141669        CMS        whole                     NaN         1.0
# 141670        CMS        whole                     NaN         1.0
# 142411        CMS        whole                     NaN         1.0
# 142412        CMS        whole                     NaN         1.0
# 142413        CMS        whole                     NaN         1.0
# 142414        CMS        whole                     NaN         1.0
# 144327        CMS        whole                     NaN         1.0
# 144328        CMS        whole                     NaN         1.0
# 144329        CMS        whole                     NaN         1.0
# 144330        CMS        whole                     NaN         1.0
# 144331        CMS        whole                     NaN         1.0
# 145690        CMS        whole                     NaN         1.0
# 145691        CMS        whole                     NaN         1.0
# 148581        CMS        whole                     NaN         1.0
# 148582        CMS        whole                     NaN         1.0
# 148583        CMS        whole                     NaN         1.0
# 148584        CMS        whole                     NaN         1.0
# 149674        CMS        whole                     NaN         1.0
# 149675        CMS        whole                     NaN         1.0
# 150873        CMS        whole                     NaN         1.0
# 150874        CMS        whole                     NaN         1.0
#
#         bloodfed_label
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# 5                False
# 6                False
# 7                False
# 8                False
# 9                False
# 10               False
# 11               False
# 12               False
# 13               False
# 14               False
# 15               False
# 16               False
# 17               False
# 18               False
# 19               False
# 20               False
# 21               False
# 22               False
# 23               False
# 24               False
# 25               False
# 26               False
# 27               False
# 28               False
# 29               False
# ...                ...
# 138064            True
# 138887            True
# 138888            True
# 138889            True
# 139559            True
# 139560            True
# 140140            True
# 140141            True
# 141668            True
# 141669            True
# 141670            True
# 142411            True
# 142412            True
# 142413            True
# 142414            True
# 144327            True
# 144328            True
# 144329            True
# 144330            True
# 144331            True
# 145690            True
# 145691            True
# 148581           False
# 148582           False
# 148583           False
# 148584           False
# 149674            True
# 149675            True
# 150873            True
# 150874            True
#
# [3193 rows x 54 columns]
