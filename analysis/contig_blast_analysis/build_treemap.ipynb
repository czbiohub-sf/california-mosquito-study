# %%
from Bio import SearchIO,SeqIO
import ete3
import os,re,requests,functools,json
from datetime import datetime as dt

ncbi=ete3.ncbi_taxonomy.NCBITaxa()
# ete3.NCBITaxa.update_taxonomy_database(ncbi)

# %%
## Download a translation of accessions to GIs and taxids
## takes ~2 hours

local_path='/Users/evogytis/Dropbox/Jupyter_notebooks/Biohub/California_mosquitoes/s3_bucket/'

for subdir, dirs, files in os.walk(local_path):
    sample=os.path.basename(subdir)
    print(sample)
    for fname in files:
        fpath=os.path.join(subdir, fname)
        if 'blast' in fname:
            blast_search=SearchIO.parse(fpath,format='blast-tab')
            if 'gsnap' in fname:
                blast_type='nt'
            elif 'rapsearch' in fname:
                blast_type='aa'
                
            done=[]
            for blast_entry in blast_search: ## iterate over queries in file
                done+=blast_entry.hit_keys ## add all hits
            
            done_set=set(done) ## keep unique
            print(len(done),len(done_set))
            done=list(done_set)
            chunkSize=240 ## how many files should be fetched
            
            done_previously=[]
            
#             d=os.path.getmtime(subdir+'/acc2gi_%s.txt'%(blast_type)) ## get modification date for file
#             dT=dt.utcfromtimestamp(d) ## convert
#             if dT.year==2019: ## check if year is recent
#             if sample!='CMS002_013a_Rb_S120_L004':
            for line in open(subdir+'/acc2gi_%s.txt'%(blast_type),'r'):
                done_previously.append(line) ## log as being known previously
                
            if len(done_previously)<2:
                out=open(subdir+'/acc2gi_%s.txt'%(blast_type),'w')

                for c,chunk in enumerate(range(0,len(done),chunkSize)): ## split accessions into chunks
                    if chunk+chunkSize<len(done):
                        accs=','.join(set(done[chunk:chunk+chunkSize]))
                    else:
                        accs=','.join(set(done[chunk:]))

                    download=None
                    ## download chunks from either nuccore or protein databases
                    if blast_type=='aa':
                        request='https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=protein&id=%s'%(accs)
                        download=requests.post(request)
                    elif blast_type=='nt':
                        request='https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=nuccore&id=%s'%(accs)
                        download=requests.post(request)

                    if download.status_code!=200:
                        raise Exception('Request failed, %s'%(request))

                    gi=re.compile('<Item Name="Gi" Type="Integer">([0-9]+)</Item>') ## fetch GI numbers
                    taxid=re.compile('<Item Name="TaxId" Type="Integer">([0-9]+)</Item>') ## fetch taxids
                    GIs=gi.findall(download.text)
                    TaxIDs=taxid.findall(download.text)

                    combine=map('\t'.join,zip(accs.split(','),GIs,TaxIDs)) ## format
                    out.write('\n'.join(combine)) ## output
                    out.write('\n')
                out.close()
# Out:
# CMS002_026d_Rb_S149_L004
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/Bio/SearchIO/_legacy/NCBIStandalone.py:45: BiopythonWarning: Parsing BLAST plain text output file is not a well supported functionality anymore. Consider generating your BLAST output for parsing as XML or tabular format instead.
#   BiopythonWarning
# 2805 1493
# 1344 325
# CMS002_045f_Rb_S189_L004
# 367 229
# 193 137
# CMS002_050a_Rb_S5_L004
# 732 234
# 68 20
# CMS002_016a_Rb_S121_L004
# 0 0
# 0 0
# CMS002_0Water2_Rb_S139_L004
# 384 237
# 214 140
# CMS002_045d_Rb_S186_L004
# 609 261
# 135 78
# CMS002_049a_Rb_S4_L004
# 32866 3601
# 109 81
# CMS001_024_Ra_S15
# 16143 3470
# 88 73
# CMS002_033a_Rb_S167_L004
# 55206 4982
# 169 134
# CMS002_028d_Rb_S157_L004
# 18822 3421
# 203 148
# CMS001_037_Ra_S21
# 22787 3187
# 290 208
# CMS002_004a_Rb_S117_L004
# 2822 985
# 494 84
# CMS002_029d_Rb_S162_L004
# 25335 3881
# 184 107
# CMS001_water4_Zymo_S27
# 2148 1295
# 1318 577

# %%
## takes ~15 minutes

local_path='/Users/evogytis/Dropbox/Jupyter_notebooks/Biohub/California_mosquitoes/s3_bucket/'

rankCounts={}
for subdir, dirs, files in os.walk(local_path): ## iterate through samples
    sample=os.path.basename(subdir) ## sample name is folder name
    
    acc_to_gi={} ## accession to gi dict
    acc_to_taxid={} ## accession to taxid dict
    search={}
    print('\n%s'%(sample))
    for fname in files: ## iterate through files in subfolders
        fpath=os.path.join(subdir, fname)
        if 'blast' in fname: ## only interested in blast outputs
            if 'gsnap' in fname:
                blast_type='nt'
            elif 'rapsearch' in fname:
                blast_type='aa'
            
            blast_search=SearchIO.parse(fpath,format='blast-tab') ## read blast output
            search[blast_type]=SearchIO.to_dict(blast_search) ## turn to dict
            
            rankCounts[sample]={} ## data for this sample will be stored in a dict
            
            for line in open(subdir+'/acc2gi_%s.txt'%(blast_type),'r'): ## load translations of accessions to GIs and taxids
                acc,gi,taxid=line.strip('\n').split('\t')
                acc_to_gi[acc]=gi
                acc_to_taxid[acc]=int(taxid)
        
        elif 'fasta' in fname: ## fasta contains contigs
            contigs=SeqIO.parse(fpath,format='fasta') ## parse fasta contigs
            seqs=SeqIO.to_dict(contigs) ## convert to dict
            print('total number of contigs in sample: %s'%(len(seqs)))
    if len(search)==2 and contigs and 'water' not in sample.lower(): ## once done with sample, if there's nt and nr blast results, contigs are loaded and they're not controls - proceed
        
        for searchType in search: ## iterate over nt or nr blast results
            no_hits=len(seqs)-len(search[searchType]) ## no hits is (total number of contigs - blast hits)
            
            if searchType=='aa':
                rankCounts[sample]['no_hit']=float(no_hits) ## keep track of how many times a contig didn't hit anything in nr
                print('number of contigs without blast hit: %d'%(no_hits))
            
            for contig in search[searchType]: ## iterate through contigs blasted
                blast_hit={} ## keep a record of hits
                bitscores={} ## keep a record of bitscores
                percent_id={} ## keep a record of percent identities
                for hit in search[searchType][contig]: ## iterate over hits to contig
                    hit_id=hit.id
                    
                    ## want to keep hits where best HSP is <1e-2 and longest match is >200 nt
                    if min([h.evalue for h in hit.hsps])<1e-2 and max([len(f) for f in hit.fragments])>200:
                        blast_hit[hit_id]=hit
                        bitscores[hit_id]=min([k.bitscore for k in hit.hsps]) ## keep track of worst HSP bitscore
                        percent_id[hit_id]=min([k.ident_pct for k in hit.hsps]) ## keep track of worst HSP percent identity
                cutoff=0.1 ## within 10% of top hit
                filteredHits=filter(lambda k: max(bitscores.values())*(1.0-cutoff)<=bitscores[k], blast_hit) ## filter hits down to those whose bitscore within 10% of the best bitscore
                hitLineages=[ncbi.get_lineage(acc_to_taxid[k]) for k in filteredHits] ## get lineage of every hit
                hitLineages=list(filter(lambda x: 7157 not in x, hitLineages)) ## filter out mosquitos
                
                if searchType=='aa': ## if nr
                    hitLineages=list(filter(lambda x: 10239 in x, hitLineages)) ## keep viruses (nr)
                elif searchType=='nt': ## if nt
                    hitLineages=list(filter(lambda x: 10239 not in x, hitLineages)) ## ignore viruses (nt)
                
                if len(list(hitLineages))>0: ## hits exist
                    lineages=sum(hitLineages,[]) ## flattened
                    T=ncbi.get_taxid_translator(lineages) ## get translation dict for every taxid present
                    ranksPresent=functools.reduce(set.intersection,map(set,hitLineages)) ## reduce lineages seen down to those that are shared by all hits
                    rankIndices={r: max([lin.index(r) for lin in hitLineages if r in lin]) for r in ranksPresent} ## find the highest rank amongst lineages that is still shared by all hits
                    highestRank=[k for k in rankIndices if rankIndices[k]==max(rankIndices.values())][-1] ## get highest
                    
                    if highestRank in rankCounts[sample]: ## rank seen before in sample
                        rankCounts[sample][highestRank]+=1 ## increment count
                    elif highestRank not in rankCounts[sample]: ## rank not seen before
                        rankCounts[sample][highestRank]=1 ## start counting
        print('contigs included in treemap: %d'%(sum(rankCounts[sample].values())))
# Out:
# CMS002_026d_Rb_S149_L004
# total number of contigs in sample: 596
# number of contigs without blast hit: 4
# contigs included in treemap: 466
#
# CMS002_045f_Rb_S189_L004
# total number of contigs in sample: 77
# number of contigs without blast hit: 0
# contigs included in treemap: 53
#
# CMS002_050a_Rb_S5_L004
# total number of contigs in sample: 173
# number of contigs without blast hit: 2
# contigs included in treemap: 18
#
# CMS002_016a_Rb_S121_L004
# total number of contigs in sample: 0
# number of contigs without blast hit: 0
# contigs included in treemap: 0
#
# CMS002_0Water2_Rb_S139_L004
# total number of contigs in sample: 82
#
# CMS002_045d_Rb_S186_L004
# total number of contigs in sample: 139
# number of contigs without blast hit: 2
# contigs included in treemap: 44
#
# CMS002_049a_Rb_S4_L004
# total number of contigs in sample: 1175
# number of contigs without blast hit: 82
# contigs included in treemap: 176
#
# CMS002_026a_Rb_S146_L004
# total number of contigs in sample: 123
# number of contigs without blast hit: 1
# contigs included in treemap: 75
#
# CMS002_0Water4_Rb_S163_L004
# total number of contigs in sample: 121
#
# CMS001_042_Ra_S23
# total number of contigs in sample: 6697
# number of contigs without blast hit: 323
# contigs included in treemap: 350
#
# CMS002_029c_Rb_S161_L004
# total number of contigs in sample: 5188
# number of contigs without blast hit: 199
# contigs included in treemap: 224
#
# CMS001_050_Ra_S23
# total number of contigs in sample: 7075
# number of contigs without blast hit: 322
# contigs included in treemap: 615
#
# CMS001_048_Ra_S5
# total number of contigs in sample: 2612
# number of contigs without blast hit: 97
# contigs included in treemap: 202
#
# CMS002_010a_Rb_S119_L004
# total number of contigs in sample: 798
# number of contigs without blast hit: 22
# contigs included in treemap: 198
#
# CMS001_058_Ra_S9
# total number of contigs in sample: 7367
# number of contigs without blast hit: 342
# contigs included in treemap: 408
#
# CMS001_009_Ra_S13
# total number of contigs in sample: 20597
# number of contigs without blast hit: 727
# contigs included in treemap: 1319
#
# CMS002_029b_Rb_S160_L004
# total number of contigs in sample: 5219
# number of contigs without blast hit: 203
# contigs included in treemap: 225
#
# CMS001_water5_RNA_A_S12
# total number of contigs in sample: 0
#
# CMS001_014_Ra_S5
# total number of contigs in sample: 11654
# number of contigs without blast hit: 1060
# contigs included in treemap: 1072
#
# CMS001_022_Ra_S6
# total number of contigs in sample: 3112
# number of contigs without blast hit: 104
# contigs included in treemap: 273
#
# CMS002_028b_Rb_S155_L004
# total number of contigs in sample: 6203
# number of contigs without blast hit: 223
# contigs included in treemap: 262
#
# CMS002_017a_Rb_S122_L004
# total number of contigs in sample: 184
# number of contigs without blast hit: 9
# contigs included in treemap: 32
#
# CMS001_039_Ra_S9
# total number of contigs in sample: 4422
# number of contigs without blast hit: 186
# contigs included in treemap: 198
#
# CMS001_015_Ra_S13
# total number of contigs in sample: 2476
# number of contigs without blast hit: 79
# contigs included in treemap: 111
#
# CMS002_027a_Rb_S152_L004
# total number of contigs in sample: 355
# number of contigs without blast hit: 8
# contigs included in treemap: 102
#
# CMS002_034a_Rb_S168_L004
# total number of contigs in sample: 3620
# number of contigs without blast hit: 156
# contigs included in treemap: 178
#
# CMS002_001a_Rb_S116_L004
# total number of contigs in sample: 822
# number of contigs without blast hit: 30
# contigs included in treemap: 185
#
# CMS001_019_Ra_S14
# total number of contigs in sample: 2042
# number of contigs without blast hit: 62
# contigs included in treemap: 141
#
# CMS002_036a_Rb_S170_L004
# total number of contigs in sample: 7825
# number of contigs without blast hit: 377
# contigs included in treemap: 419
#
# CMS002_032a_Rb_S166_L004
# total number of contigs in sample: 14408
# number of contigs without blast hit: 987
# contigs included in treemap: 1023
#
# CMS002_0Water5_Rb_S175_L004
# total number of contigs in sample: 101
#
# CMS002_007a_Rb_S118_L004
# total number of contigs in sample: 37488
# number of contigs without blast hit: 4454
# contigs included in treemap: 4516
#
# CMS002_047g_Rb_S200_L004
# total number of contigs in sample: 2902
# number of contigs without blast hit: 110
# contigs included in treemap: 157
#
# CMS001_002_Ra_S1
# total number of contigs in sample: 4929
# number of contigs without blast hit: 242
# contigs included in treemap: 267
#
# CMS002_029a_Rb_S159_L004
# total number of contigs in sample: 11348
# number of contigs without blast hit: 576
# contigs included in treemap: 624
#
# CMS002_028e_Rb_S158_L004
# total number of contigs in sample: 8602
# number of contigs without blast hit: 442
# contigs included in treemap: 1067
#
# CMS002_018b_Rb_S129_L004
# total number of contigs in sample: 400
# number of contigs without blast hit: 16
# contigs included in treemap: 67
#
# CMS001_007_Ra_S12
# total number of contigs in sample: 4009
# number of contigs without blast hit: 76
# contigs included in treemap: 92
#
# CMS002_025e_Rb_S144_L004
# total number of contigs in sample: 273
# number of contigs without blast hit: 4
# contigs included in treemap: 64
#
# CMS002_0Water7_Rb_S199_L004
# total number of contigs in sample: 106
#
# CMS002_026c_Rb_S148_L004
# total number of contigs in sample: 520
# number of contigs without blast hit: 3
# contigs included in treemap: 438
#
# CMS001_041_Ra_S10
# total number of contigs in sample: 1069
# number of contigs without blast hit: 46
# contigs included in treemap: 424
#
# CMS001_026_Ra_S18
# total number of contigs in sample: 21264
# number of contigs without blast hit: 2162
# contigs included in treemap: 2194
#
# CMS001_057_Ra_S11
# total number of contigs in sample: 6213
# number of contigs without blast hit: 247
# contigs included in treemap: 443
#
# CMS002_045a_Rb_S183_L004
# total number of contigs in sample: 214
# number of contigs without blast hit: 3
# contigs included in treemap: 122
#
# CMS002_022a_Rb_S137_L004
# total number of contigs in sample: 1124
# number of contigs without blast hit: 47
# contigs included in treemap: 151
#
# CMS001_044_Ra_S25
# total number of contigs in sample: 610
# number of contigs without blast hit: 31
# contigs included in treemap: 102
#
# CMS002_047j_Rb_S3_L004
# total number of contigs in sample: 5708
# number of contigs without blast hit: 258
# contigs included in treemap: 314
#
# CMS002_0Water1_Rb_S127_L004
# total number of contigs in sample: 74
#
# CMS002_039a_Rb_S173_L004
# total number of contigs in sample: 12653
# number of contigs without blast hit: 715
# contigs included in treemap: 748
#
# CMS002_051a_Rb_S6_L004
# total number of contigs in sample: 881
# number of contigs without blast hit: 29
# contigs included in treemap: 115
#
# CMS002_017e_Rb_S126_L004
# total number of contigs in sample: 185
# number of contigs without blast hit: 15
# contigs included in treemap: 46
#
# CMS001_water1_S11
# total number of contigs in sample: 0
#
# CMS002_023a_Rb_S138_L004
# total number of contigs in sample: 514
# number of contigs without blast hit: 31
# contigs included in treemap: 79
#
# CMS002_025c_Rb_S142_L004
# total number of contigs in sample: 204
# number of contigs without blast hit: 6
# contigs included in treemap: 58
#
# CMS002_021a_Rb_S136_L004
# total number of contigs in sample: 49881
# number of contigs without blast hit: 7242
# contigs included in treemap: 7324
#
# CMS002_042a_Rb_S177_L004
# total number of contigs in sample: 2955
# number of contigs without blast hit: 133
# contigs included in treemap: 216
#
# CMS001_034_Ra_S19
# total number of contigs in sample: 3655
# number of contigs without blast hit: 157
# contigs included in treemap: 173
#
# CMS002_056a_Rb_S9_L004
# total number of contigs in sample: 10844
# number of contigs without blast hit: 633
# contigs included in treemap: 698
#
# CMS001_060_Ra_S12
# total number of contigs in sample: 29705
# number of contigs without blast hit: 3455
# contigs included in treemap: 3577
#
# CMS002_041a_Rb_S176_L004
# total number of contigs in sample: 7446
# number of contigs without blast hit: 451
# contigs included in treemap: 806
#
# CMS002_044e_Rb_S182_L004
# total number of contigs in sample: 171
# number of contigs without blast hit: 5
# contigs included in treemap: 53
#
# CMS001_011_Ra_S4
# total number of contigs in sample: 6193
# number of contigs without blast hit: 225
# contigs included in treemap: 338
#
# CMS001_028_Ra_S17
# total number of contigs in sample: 4865
# number of contigs without blast hit: 145
# contigs included in treemap: 225
#
# CMS001_001_Ra_S1
# total number of contigs in sample: 11896
# number of contigs without blast hit: 677
# contigs included in treemap: 1210
#
# CMS002_025a_Rb_S140_L004
# total number of contigs in sample: 18
# number of contigs without blast hit: 0
# contigs included in treemap: 10
#
# CMS001_059_Ra_S10
# total number of contigs in sample: 1311
# number of contigs without blast hit: 63
# contigs included in treemap: 411
#
# CMS002_044a_Rb_S178_L004
# total number of contigs in sample: 272
# number of contigs without blast hit: 9
# contigs included in treemap: 44
#
# CMS001_008_Ra_S3
# total number of contigs in sample: 13396
# number of contigs without blast hit: 1292
# contigs included in treemap: 1354
#
# CMS002_047b_Rb_S194_L004
# total number of contigs in sample: 2522
# number of contigs without blast hit: 84
# contigs included in treemap: 148
#
# CMS001_013_Ra_S5
# total number of contigs in sample: 7071
# number of contigs without blast hit: 313
# contigs included in treemap: 372
#
# CMS002_025d_Rb_S143_L004
# total number of contigs in sample: 0
# number of contigs without blast hit: 0
# contigs included in treemap: 0
#
# CMS001_036_Ra_S20
# total number of contigs in sample: 15097
# number of contigs without blast hit: 1085
# contigs included in treemap: 1335
#
# CMS002_040a_Rb_S174_L004
# total number of contigs in sample: 6610
# number of contigs without blast hit: 286
# contigs included in treemap: 317
#
# CMS002_047c_Rb_S195_L004
# total number of contigs in sample: 7295
# number of contigs without blast hit: 326
# contigs included in treemap: 407
#
# CMS001_025_Ra_S7
# total number of contigs in sample: 16379
# number of contigs without blast hit: 1419
# contigs included in treemap: 1458
#
# CMS002_0Water3_Rb_S151_L004
# total number of contigs in sample: 112
#
# CMS001_004_Ra_S2
# total number of contigs in sample: 836
# number of contigs without blast hit: 26
# contigs included in treemap: 249
#
# CMS002_029e_Rb_S164_L004
# total number of contigs in sample: 1909
# number of contigs without blast hit: 80
# contigs included in treemap: 108
#
# CMS002_044d_Rb_S181_L004
# total number of contigs in sample: 304
# number of contigs without blast hit: 8
# contigs included in treemap: 74
#
# CMS001_021_Ra_S16
# total number of contigs in sample: 12284
# number of contigs without blast hit: 607
# contigs included in treemap: 637
#
# CMS001_053_Ra_S8
# total number of contigs in sample: 2587
# number of contigs without blast hit: 90
# contigs included in treemap: 141
#
# CMS002_020d_Rb_S134_L004
# total number of contigs in sample: 10292
# number of contigs without blast hit: 832
# contigs included in treemap: 849
#
# CMS001_030_Ra_S7
# total number of contigs in sample: 1004
# number of contigs without blast hit: 49
# contigs included in treemap: 224
#
# CMS001_016_Ra_S6
# total number of contigs in sample: 21018
# number of contigs without blast hit: 2437
# contigs included in treemap: 2548
#
# CMS002_047d_Rb_S196_L004
# total number of contigs in sample: 7764
# number of contigs without blast hit: 369
# contigs included in treemap: 410
#
# CMS001_043_Ra_S24
# total number of contigs in sample: 5072
# number of contigs without blast hit: 278
# contigs included in treemap: 473
#
# CMS001_water3_Qiagen_S26
# total number of contigs in sample: 6169
#
# CMS001_020_Ra_S15
# total number of contigs in sample: 6417
# number of contigs without blast hit: 291
# contigs included in treemap: 348
#
# CMS002_047i_Rb_S2_L004
# total number of contigs in sample: 5774
# number of contigs without blast hit: 246
# contigs included in treemap: 274
#
# CMS001_051_Ra_S8
# total number of contigs in sample: 8676
# number of contigs without blast hit: 399
# contigs included in treemap: 420
#
# CMS002_044b_Rb_S179_L004
# total number of contigs in sample: 62
# number of contigs without blast hit: 3
# contigs included in treemap: 14
#
# CMS002_025b_Rb_S141_L004
# total number of contigs in sample: 40
# number of contigs without blast hit: 1
# contigs included in treemap: 24
#
# CMS001_032_Ra_S7
# total number of contigs in sample: 2669
# number of contigs without blast hit: 191
# contigs included in treemap: 698
#
# CMS002_017d_Rb_S125_L004
# total number of contigs in sample: 212
# number of contigs without blast hit: 7
# contigs included in treemap: 36
#
# CMS002_038a_Rb_S172_L004
# total number of contigs in sample: 10828
# number of contigs without blast hit: 567
# contigs included in treemap: 609
#
# CMS002_047e_Rb_S197_L004
# total number of contigs in sample: 5777
# number of contigs without blast hit: 233
# contigs included in treemap: 269
#
# CMS001_006_Ra_S5
# total number of contigs in sample: 7740
# number of contigs without blast hit: 390
# contigs included in treemap: 456
#
# CMS002_020e_Rb_S135_L004
# total number of contigs in sample: 18006
# number of contigs without blast hit: 1942
# contigs included in treemap: 1966
#
# CMS002_0Water6_Rb_S187_L004
# total number of contigs in sample: 38
#
# CMS002_0Water8_Rb_S11_L004
# total number of contigs in sample: 0
#
# CMS001_040_Ra_S21
# total number of contigs in sample: 2053
# number of contigs without blast hit: 76
# contigs included in treemap: 100
#
# CMS002_054a_Rb_S8_L004
# total number of contigs in sample: 375
# number of contigs without blast hit: 19
# contigs included in treemap: 48
#
# CMS001_031_Ra_S19
# total number of contigs in sample: 4721
# number of contigs without blast hit: 208
# contigs included in treemap: 289
#
# CMS001_023_Ra_S17
# total number of contigs in sample: 3713
# number of contigs without blast hit: 106
# contigs included in treemap: 183
#
# CMS001_010_Ra_S1
# total number of contigs in sample: 2854
# number of contigs without blast hit: 101
# contigs included in treemap: 131
#
# CMS002_017c_Rb_S124_L004
# total number of contigs in sample: 234
# number of contigs without blast hit: 18
# contigs included in treemap: 68
#
# CMS002_053a_Rb_S7_L004
# total number of contigs in sample: 41366
# number of contigs without blast hit: 2443
# contigs included in treemap: 2570
#
# CMS001_047_Ra_S4
# total number of contigs in sample: 2936
# number of contigs without blast hit: 114
# contigs included in treemap: 298
#
# CMS002_047f_Rb_S198_L004
# total number of contigs in sample: 5212
# number of contigs without blast hit: 204
# contigs included in treemap: 259
#
# CMS002_044c_Rb_S180_L004
# total number of contigs in sample: 166
# number of contigs without blast hit: 5
# contigs included in treemap: 36
#
# CMS001_045_Ra_S2
# total number of contigs in sample: 4270
# number of contigs without blast hit: 177
# contigs included in treemap: 323
#
# CMS001_055_Ra_S9
# total number of contigs in sample: 2423
# number of contigs without blast hit: 117
# contigs included in treemap: 122
#
# CMS001_018_Ra_S14
# total number of contigs in sample: 2598
# number of contigs without blast hit: 60
# contigs included in treemap: 113
#
# CMS002_047h_Rb_S1_L004
# total number of contigs in sample: 5498
# number of contigs without blast hit: 229
# contigs included in treemap: 267
#
# CMS002_018a_Rb_S128_L004
# total number of contigs in sample: 37
# number of contigs without blast hit: 5
# contigs included in treemap: 8
#
# CMS001_005_Ra_S3
# total number of contigs in sample: 23596
# number of contigs without blast hit: 2559
# contigs included in treemap: 2614
#
# CMS002_028c_Rb_S156_L004
# total number of contigs in sample: 5929
# number of contigs without blast hit: 226
# contigs included in treemap: 263
#
# CMS002_025f_Rb_S145_L004
# total number of contigs in sample: 0
# number of contigs without blast hit: 0
# contigs included in treemap: 0
#
# CMS002_047a_Rb_S193_L004
# total number of contigs in sample: 6003
# number of contigs without blast hit: 218
# contigs included in treemap: 271
#
# CMS001_049_Ra_S6
# total number of contigs in sample: 2574
# number of contigs without blast hit: 76
# contigs included in treemap: 147
#
# CMS001_056_Ra_S10
# total number of contigs in sample: 2143
# number of contigs without blast hit: 63
# contigs included in treemap: 96
#
# CMS001_052_Ra_S7
# total number of contigs in sample: 2881
# number of contigs without blast hit: 121
# contigs included in treemap: 166
#
# CMS002_026e_Rb_S150_L004
# total number of contigs in sample: 314
# number of contigs without blast hit: 1
# contigs included in treemap: 214
#
# CMS002_045g_Rb_S190_L004
# total number of contigs in sample: 96
# number of contigs without blast hit: 1
# contigs included in treemap: 51
#
# CMS002_020a_Rb_S131_L004
# total number of contigs in sample: 45574
# number of contigs without blast hit: 6158
# contigs included in treemap: 6184
#
# CMS001_water2_S24
# total number of contigs in sample: 196
#
# CMS002_027b_Rb_S153_L004
# total number of contigs in sample: 1389
# number of contigs without blast hit: 34
# contigs included in treemap: 372
#
# CMS001_033_Ra_S8
# total number of contigs in sample: 6935
# number of contigs without blast hit: 346
# contigs included in treemap: 379
#
# CMS002_057a_Rb_S10_L004
# total number of contigs in sample: 623
# number of contigs without blast hit: 24
# contigs included in treemap: 87
#
# CMS002_046b_Rb_S192_L004
# total number of contigs in sample: 1119
# number of contigs without blast hit: 40
# contigs included in treemap: 275
#
# CMS002_013a_Rb_S120_L004
# total number of contigs in sample: 1716
# number of contigs without blast hit: 85
# contigs included in treemap: 545
#
# CMS001_017_Ra_S6
# total number of contigs in sample: 7223
# number of contigs without blast hit: 361
# contigs included in treemap: 380
#
# CMS001_035_Ra_S20
# total number of contigs in sample: 6126
# number of contigs without blast hit: 178
# contigs included in treemap: 584
#
# CMS001_038_Ra_S22
# total number of contigs in sample: 4575
# number of contigs without blast hit: 197
# contigs included in treemap: 278
#
# CMS001_027_Ra_S16
# total number of contigs in sample: 4251
# number of contigs without blast hit: 104
# contigs included in treemap: 389
#
# CMS002_045b_Rb_S184_L004
# total number of contigs in sample: 261
# number of contigs without blast hit: 7
# contigs included in treemap: 68
#
# CMS001_046_Ra_S3
# total number of contigs in sample: 2156
# number of contigs without blast hit: 74
# contigs included in treemap: 117
#
# CMS002_020c_Rb_S133_L004
# total number of contigs in sample: 8437
# number of contigs without blast hit: 767
# contigs included in treemap: 805
#
# CMS002_031a_Rb_S165_L004
# total number of contigs in sample: 8136
# number of contigs without blast hit: 466
# contigs included in treemap: 611
#
# CMS001_029_Ra_S18
# total number of contigs in sample: 1154
# number of contigs without blast hit: 17
# contigs included in treemap: 539
#
# CMS002_046a_Rb_S191_L004
# total number of contigs in sample: 963
# number of contigs without blast hit: 27
# contigs included in treemap: 295
#
# CMS001_054_Ra_S11
# total number of contigs in sample: 573
# number of contigs without blast hit: 17
# contigs included in treemap: 214
#
# CMS002_017b_Rb_S123_L004
# total number of contigs in sample: 267
# number of contigs without blast hit: 8
# contigs included in treemap: 61
#
# CMS002_028a_Rb_S154_L004
# total number of contigs in sample: 5396
# number of contigs without blast hit: 198
# contigs included in treemap: 219
#
# CMS002_045e_Rb_S188_L004
# total number of contigs in sample: 226
# number of contigs without blast hit: 1
# contigs included in treemap: 39
#
# CMS002_035a_Rb_S169_L004
# total number of contigs in sample: 14201
# number of contigs without blast hit: 874
# contigs included in treemap: 936
#
# CMS002_020b_Rb_S132_L004
# total number of contigs in sample: 4937
# number of contigs without blast hit: 544
# contigs included in treemap: 584
#
# CMS001_003_Ra_S2
# total number of contigs in sample: 17208
# number of contigs without blast hit: 1884
# contigs included in treemap: 2073
#
# CMS002_019a_Rb_S130_L004
# total number of contigs in sample: 352
# number of contigs without blast hit: 26
# contigs included in treemap: 54
#
# CMS002_026b_Rb_S147_L004
# total number of contigs in sample: 161
# number of contigs without blast hit: 0
# contigs included in treemap: 129
#
# CMS002_045c_Rb_S185_L004
# total number of contigs in sample: 102
# number of contigs without blast hit: 1
# contigs included in treemap: 47
#
# CMS002_037a_Rb_S171_L004
# total number of contigs in sample: 8566
# number of contigs without blast hit: 407
# contigs included in treemap: 430
#
# CMS001_024_Ra_S15
# total number of contigs in sample: 3674
# number of contigs without blast hit: 63
# contigs included in treemap: 78
#
# CMS002_033a_Rb_S167_L004
# total number of contigs in sample: 14822
# number of contigs without blast hit: 804
# contigs included in treemap: 827
#
# CMS002_028d_Rb_S157_L004
# total number of contigs in sample: 4634
# number of contigs without blast hit: 187
# contigs included in treemap: 233
#
# CMS001_037_Ra_S21
# total number of contigs in sample: 5980
# number of contigs without blast hit: 321
# contigs included in treemap: 429
#
# CMS002_004a_Rb_S117_L004
# total number of contigs in sample: 642
# number of contigs without blast hit: 20
# contigs included in treemap: 140
#
# CMS002_029d_Rb_S162_L004
# total number of contigs in sample: 6400
# number of contigs without blast hit: 250
# contigs included in treemap: 277
#
# CMS001_water4_Zymo_S27
# total number of contigs in sample: 449

# %%
sanitise=re.compile('[\(\),\[\]\;\'\"]') ## used to remove crud from rank names that might interfere later

branch_hash={} ## will contain branches of taxonomy tree

links={} ## will link parents to children
no_hit={'taxonomy':'no blast hit','taxid':'no_hit','attrs':{}} ## the no-hit branch

for sample in rankCounts: ## iterate through samples
    ranks=rankCounts[sample] ## get the rank counts in sample
    taxidT=ncbi.get_taxid_translator(sum([ncbi.get_lineage(r) for r in ranks.keys() if r!='no_hit'],[])) ## get taxid translation
    
    if 'no_hit' in ranks:
        no_hit['attrs']['%s_count'%(sample)]=ranks['no_hit'] ## annotate no-hit branch with sample's no-hit count
        
    for r,rank in enumerate(ranks): ## iterate over taxonomic ranks seen in sample
        if rank not in branch_hash: ## taxon not seen in previous loops
            branch_hash[rank]={'attrs':{}} ## create new branch
            if rank!='no_hit':
                branch_hash[rank]['taxonomy']=str(re.sub(sanitise,'',taxidT[rank])) ## sanitise name
                branch_hash[rank]['taxid']=rank
                
        branch_hash[rank]['attrs']['%s_count'%(sample)]=ranks[rank] ## add contig count to branch
            
        lineage=None
        try:
            lineage=ncbi.get_lineage(rank) ## try getting lineage of rank
        except:
            pass

        if lineage: ## lineage available (.get_lineage() didn't fail)
            if 2 in lineage: ## Bacteria
                colour='indianred'
            elif 2759 in lineage: ## Eukaryota
                colour='skyblue'
            elif 2157 in lineage: ## Archaea
                colour='steelblue'
            elif 10239 in lineage: ## Viruses
                colour='slategrey'
                
            for i in range(len(lineage)-1): ## iterate over lineage - store parent-child links
                cur=lineage[::-1][i] ## starting from most recent, heading deeper
                par=lineage[::-1][i+1] ## next in line
                
                if cur not in branch_hash: ## taxid not seen before - create it
                    branch_hash[cur]={'taxid':cur,'taxonomy':taxidT[cur],'attrs':{'count':0.0}}
                if par not in branch_hash:
                    branch_hash[par]={'taxid':par,'taxonomy':taxidT[par],'attrs':{'count':0.0}}
                
                branch_hash[cur]['colour']=colour
                branch_hash[par]['colour']=colour
                if cur==131567:
                    branch_hash[cur]['colour']='lightgrey'
                elif par==131567:
                    branch_hash[par]['colour']='lightgrey'
                
                links[cur]=par ## remember link

json_tree={'children':[no_hit]} ## root of the tree has one child to begin with - the no-hit branch

no_hit['attrs']['count']=sum([no_hit['attrs'][w] for w in no_hit['attrs'] if '_count' in w]) ## sum no hits
for k in branch_hash: ## iterate through branches
    branch_hash[k]['attrs']['count']=sum([branch_hash[k]['attrs'][w] for w in branch_hash[k]['attrs'] if '_count' in w]) ## compute total counts from individual sample scores

for cur in links: ## iterate through parent-child links
    par=links[cur]
    child=branch_hash[cur] ## get child
    parent=branch_hash[par] ## get parent
    if 'children' not in parent: ## parent hasn't had children - add it
        parent['children']=[] ## children are stored in a list
        
    if child not in parent['children']: ## child is not yet present
        parent['children'].append(child) ## add child to parent
    if par==1 and parent not in json_tree['children']: ## at root of the tree
        json_tree['children'].append(parent) ## add root to tree
        
# print(json_tree)
json.dump(json_tree,open('/Users/evogytis/Dropbox/Jupyter_notebooks/Biohub/California_mosquitoes/test_skeeters.json','w'),indent=1)

# %%
## can check for contig numbers of individual samples
j=json.load(open('/Users/evogytis/Dropbox/Jupyter_notebooks/Biohub/California_mosquitoes/test_skeeters.json','r'))

# sample='CMS002_028a_Rb_S154_L004_count'
## sample contains 5396 contigs (5378 >200 nt)

sample='CMS002_029e_Rb_S164_L004_count'
## 1908 contigs >200 nt

global accumulate
accumulate=0.0
def walkJ(j,sample):
    global accumulate
    if 'attrs' in j and sample in j['attrs']:
        accumulate+=j['attrs'][sample]
    if 'children' in j:
        for child in j['children']:
            walkJ(child,sample)

walkJ(j,sample)
print(accumulate)
# Out:
# 108.0
