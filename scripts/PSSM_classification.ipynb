# %% [markdown]
# ## Building PSSM profiles from alignments

# %%
# %%bash
#
# base_path=/Users/evogytis/Documents/manuscripts/skeeters/data/darkmatter/RdRp_profiles ## where alignments are kept
# cd $base_path
#
# for msa in *full.fasta ## iterate over alignments of each Pfam group
#     do
#     echo $msa
#     out=${msa/_full.fasta/_pssm.txt}
#     hmmbuild $out $msa ## build PSSM
#
# done;
#
# cat *_pssm.txt > RdRp_profiles.pssm.txt ## concatenate Pfam PSSMs into a single file
# hmmpress -f RdRp_profiles.pssm.txt ## compress for search
# Out:
# ArenaRdRp_PF06317_full.fasta
# # hmmbuild :: profile HMM construction from multiple sequence alignments
# # HMMER 3.1b2 (February 2015); http://hmmer.org/
# # Copyright (C) 2015 Howard Hughes Medical Institute.
# # Freely distributed under the GNU General Public License (GPLv3).
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # input alignment file:             ArenaRdRp_PF06317_full.fasta
# # output HMM file:                  ArenaRdRp_PF06317_pssm.txt
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# # idx name                  nseq  alen  mlen eff_nseq re/pos description
# #---- -------------------- ----- ----- ----- -------- ------ -----------
# 1     ArenaRdRp_PF06317_full    16  2640  1096     1.62  0.591
#
# # CPU time: 2.29u 0.03s 00:00:02.31 Elapsed: 00:00:02.79
# BirnaRdRp_PF04197_full.fasta
# # hmmbuild :: profile HMM construction from multiple sequence alignments
# # HMMER 3.1b2 (February 2015); http://hmmer.org/
# # Copyright (C) 2015 Howard Hughes Medical Institute.
# # Freely distributed under the GNU General Public License (GPLv3).
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # input alignment file:             BirnaRdRp_PF04197_full.fasta
# # output HMM file:                  BirnaRdRp_PF04197_pssm.txt
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# # idx name                  nseq  alen  mlen eff_nseq re/pos description
# #---- -------------------- ----- ----- ----- -------- ------ -----------
# 1     BirnaRdRp_PF04197_full     8  1078   846     1.04  0.590
#
# # CPU time: 1.58u 0.02s 00:00:01.60 Elapsed: 00:00:01.95
# BromoTobamoTogaRdRp_PF00978_full.fasta
# # hmmbuild :: profile HMM construction from multiple sequence alignments
# # HMMER 3.1b2 (February 2015); http://hmmer.org/
# # Copyright (C) 2015 Howard Hughes Medical Institute.
# # Freely distributed under the GNU General Public License (GPLv3).
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # input alignment file:             BromoTobamoTogaRdRp_PF00978_full.fasta
# # output HMM file:                  BromoTobamoTogaRdRp_PF00978_pssm.txt
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# # idx name                  nseq  alen  mlen eff_nseq re/pos description
# #---- -------------------- ----- ----- ----- -------- ------ -----------
# 1     BromoTobamoTogaRdRp_PF00978_full   367  1199   311     8.55  0.590
#
# # CPU time: 0.94u 0.01s 00:00:00.95 Elapsed: 00:00:01.75
# BunyaRdRp_PF04196_full.fasta
# # hmmbuild :: profile HMM construction from multiple sequence alignments
# # HMMER 3.1b2 (February 2015); http://hmmer.org/
# # Copyright (C) 2015 Howard Hughes Medical Institute.
# # Freely distributed under the GNU General Public License (GPLv3).
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # input alignment file:             BunyaRdRp_PF04196_full.fasta
# # output HMM file:                  BunyaRdRp_PF04196_pssm.txt
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# # idx name                  nseq  alen  mlen eff_nseq re/pos description
# #---- -------------------- ----- ----- ----- -------- ------ -----------
# 1     BunyaRdRp_PF04196_full   157  1488   708     8.02  0.590
#
# # CPU time: 1.69u 0.02s 00:00:01.71 Elapsed: 00:00:02.24
# FlaviRdRp_PF00972_full.fasta
# # hmmbuild :: profile HMM construction from multiple sequence alignments
# # HMMER 3.1b2 (February 2015); http://hmmer.org/
# # Copyright (C) 2015 Howard Hughes Medical Institute.
# # Freely distributed under the GNU General Public License (GPLv3).
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # input alignment file:             FlaviRdRp_PF00972_full.fasta
# # output HMM file:                  FlaviRdRp_PF00972_pssm.txt
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# # idx name                  nseq  alen  mlen eff_nseq re/pos description
# #---- -------------------- ----- ----- ----- -------- ------ -----------
# 1     FlaviRdRp_PF00972_full    15   844   549     1.83  0.590
#
# # CPU time: 1.27u 0.02s 00:00:01.29 Elapsed: 00:00:01.62
# LuteoTotiRotaRdRp_PF02123_full.fasta
# # hmmbuild :: profile HMM construction from multiple sequence alignments
# # HMMER 3.1b2 (February 2015); http://hmmer.org/
# # Copyright (C) 2015 Howard Hughes Medical Institute.
# # Freely distributed under the GNU General Public License (GPLv3).
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # input alignment file:             LuteoTotiRotaRdRp_PF02123_full.fasta
# # output HMM file:                  LuteoTotiRotaRdRp_PF02123_pssm.txt
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# # idx name                  nseq  alen  mlen eff_nseq re/pos description
# #---- -------------------- ----- ----- ----- -------- ------ -----------
# 1     LuteoTotiRotaRdRp_PF02123_full   200  1340   359    12.25  0.590
#
# # CPU time: 0.94u 0.01s 00:00:00.95 Elapsed: 00:00:01.05
# MitoRdRp_PF05919_full.fasta
# # hmmbuild :: profile HMM construction from multiple sequence alignments
# # HMMER 3.1b2 (February 2015); http://hmmer.org/
# # Copyright (C) 2015 Howard Hughes Medical Institute.
# # Freely distributed under the GNU General Public License (GPLv3).
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # input alignment file:             MitoRdRp_PF05919_full.fasta
# # output HMM file:                  MitoRdRp_PF05919_pssm.txt
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# # idx name                  nseq  alen  mlen eff_nseq re/pos description
# #---- -------------------- ----- ----- ----- -------- ------ -----------
# 1     MitoRdRp_PF05919_full   141   989   240     4.71  0.590
#
# # CPU time: 0.52u 0.00s 00:00:00.52 Elapsed: 00:00:00.55
# MononegaRdRp_PF00946_full.fasta
# # hmmbuild :: profile HMM construction from multiple sequence alignments
# # HMMER 3.1b2 (February 2015); http://hmmer.org/
# # Copyright (C) 2015 Howard Hughes Medical Institute.
# # Freely distributed under the GNU General Public License (GPLv3).
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # input alignment file:             MononegaRdRp_PF00946_full.fasta
# # output HMM file:                  MononegaRdRp_PF00946_pssm.txt
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# # idx name                  nseq  alen  mlen eff_nseq re/pos description
# #---- -------------------- ----- ----- ----- -------- ------ -----------
# 1     MononegaRdRp_PF00946_full   356  2584   849     7.43  0.590
#
# # CPU time: 2.44u 0.03s 00:00:02.46 Elapsed: 00:00:02.88
# OrthomyxoRdRp_PF00602_full.fasta
# # hmmbuild :: profile HMM construction from multiple sequence alignments
# # HMMER 3.1b2 (February 2015); http://hmmer.org/
# # Copyright (C) 2015 Howard Hughes Medical Institute.
# # Freely distributed under the GNU General Public License (GPLv3).
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # input alignment file:             OrthomyxoRdRp_PF00602_full.fasta
# # output HMM file:                  OrthomyxoRdRp_PF00602_pssm.txt
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# # idx name                  nseq  alen  mlen eff_nseq re/pos description
# #---- -------------------- ----- ----- ----- -------- ------ -----------
# 1     OrthomyxoRdRp_PF00602_full    59   878   700     1.96  0.590
#
# # CPU time: 1.62u 0.03s 00:00:01.65 Elapsed: 00:00:02.19
# Partitiviridae_ICTV_Mafft_211216_full.fasta
# # hmmbuild :: profile HMM construction from multiple sequence alignments
# # HMMER 3.1b2 (February 2015); http://hmmer.org/
# # Copyright (C) 2015 Howard Hughes Medical Institute.
# # Freely distributed under the GNU General Public License (GPLv3).
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # input alignment file:             Partitiviridae_ICTV_Mafft_211216_full.fasta
# # output HMM file:                  Partitiviridae_ICTV_Mafft_211216_pssm.txt
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# # idx name                  nseq  alen  mlen eff_nseq re/pos description
# #---- -------------------- ----- ----- ----- -------- ------ -----------
# 1     Partitiviridae_ICTV_Mafft_211216_full    45   907   623     4.11  0.590
#
# # CPU time: 1.48u 0.03s 00:00:01.51 Elapsed: 00:00:02.15
# PicornaRdRp_PF00680_full.fasta
# # hmmbuild :: profile HMM construction from multiple sequence alignments
# # HMMER 3.1b2 (February 2015); http://hmmer.org/
# # Copyright (C) 2015 Howard Hughes Medical Institute.
# # Freely distributed under the GNU General Public License (GPLv3).
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # input alignment file:             PicornaRdRp_PF00680_full.fasta
# # output HMM file:                  PicornaRdRp_PF00680_pssm.txt
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# # idx name                  nseq  alen  mlen eff_nseq re/pos description
# #---- -------------------- ----- ----- ----- -------- ------ -----------
# 1     PicornaRdRp_PF00680_full   704  1806   398    13.75  0.590
#
# # CPU time: 1.34u 0.03s 00:00:01.37 Elapsed: 00:00:02.17
# ReoRdRp_PF07925_full.fasta
# # hmmbuild :: profile HMM construction from multiple sequence alignments
# # HMMER 3.1b2 (February 2015); http://hmmer.org/
# # Copyright (C) 2015 Howard Hughes Medical Institute.
# # Freely distributed under the GNU General Public License (GPLv3).
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # input alignment file:             ReoRdRp_PF07925_full.fasta
# # output HMM file:                  ReoRdRp_PF07925_pssm.txt
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# # idx name                  nseq  alen  mlen eff_nseq re/pos description
# #---- -------------------- ----- ----- ----- -------- ------ -----------
# 1     ReoRdRp_PF07925_full    16  1360  1252     1.15  0.590
#
# # CPU time: 2.50u 0.03s 00:00:02.52 Elapsed: 00:00:03.30
# Reo_alternative_full.fasta
# # hmmbuild :: profile HMM construction from multiple sequence alignments
# # HMMER 3.1b2 (February 2015); http://hmmer.org/
# # Copyright (C) 2015 Howard Hughes Medical Institute.
# # Freely distributed under the GNU General Public License (GPLv3).
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # input alignment file:             Reo_alternative_full.fasta
# # output HMM file:                  Reo_alternative_pssm.txt
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# # idx name                  nseq  alen  mlen eff_nseq re/pos description
# #---- -------------------- ----- ----- ----- -------- ------ -----------
# 1     Reo_alternative_full    50  1792  1229     4.57  0.590
#
# # CPU time: 2.71u 0.04s 00:00:02.75 Elapsed: 00:00:04.08
# Working...    done.
# Pressed and indexed 13 HMMs (13 names).
# Models pressed into binary file:   RdRp_profiles.pssm.txt.h3m
# SSI index for binary model file:   RdRp_profiles.pssm.txt.h3i
# Profiles (MSV part) pressed into:  RdRp_profiles.pssm.txt.h3f
# Profiles (remainder) pressed into: RdRp_profiles.pssm.txt.h3p

# %% [markdown]
# ## Extract representative contigs of each cluster

# %%
import pandas as pd
from collections import defaultdict, namedtuple
import os,re,glob
from Bio import SeqIO

Member = namedtuple('Member', ['contig', 'length', 'percent_id', 'percent_id_sign', 'sample',
                               'coverage', 'uuid', 'reads'])

base_path='/Users/evogytis/Documents/manuscripts/skeeters/data/'

# Use abundance information from mapping reads back to contigs
count_df = pd.read_csv('/Users/evogytis/Downloads/contig_counts.csv')
count_df['uuid'] = count_df['sample'] + '~' + count_df['contig']
count_lookup = {uuid: counts for uuid, counts in zip(count_df['uuid'], count_df['counts'])}

def parse_cdhit_row(row):
    if '*' in row:
        index, length, name, percent_id = row.split()
        percent_id_sign, percent_id = '0', 100
    else:
        index, length, name, _, percent_id = row.split()
    length = int(length.strip(',nt'))
    name = name.strip('>').strip('.')
    uuid = name
    sample, contig = name.split('~')
    coverage = float(contig.split('_')[-1])
    reads = count_lookup[uuid] if uuid in count_lookup else 0
    
    if percent_id != 100:
        percent_id_sign, percent_id = percent_id.strip('%').split('/')
        percent_id = float(percent_id)
        
    return Member(contig=contig, sample=sample, length=length,
                  percent_id=percent_id, percent_id_sign=percent_id_sign, coverage=coverage,
                  uuid=uuid, reads=reads)

clusters = defaultdict(list)
with open(os.path.join(base_path,'500_contigs_cluster.clstr'), 'r') as file:
    for line in file:
        if line.startswith('>Cluster'):
            cluster_id = line.split()[-1]
        else:
            member = parse_cdhit_row(line)
            if 'water' in member.sample.lower():
                continue
            clusters[cluster_id].append(member)
            
def get_representative(cluster):
    representative = [member for member in cluster if member.percent_id_sign == '0'][0]
    return representative

fetch={} ## cluster ID of representative contig
for clustID in clusters:
    try:
        representative_contig=get_representative(clusters[clustID])
        fetch[representative_contig.contig]=clustID
    except:
        print(clustID,'failed, probably because longest contig is from water')

store_representatives=open(os.path.join(base_path,'darkmatter/representative_contigs.fasta'),'w')

for contig_file in glob.glob(os.path.join(base_path,'s3/contigs','*','contigs.fasta')):
    sample=os.path.basename(os.path.dirname(contig_file))
    for seq in SeqIO.parse(open(contig_file,'r'),format='fasta'):
        if seq.id in fetch:
            seq_name=seq.id
            cluster_id=fetch[seq_name]
            seq=str(seq.seq)
            
            store_representatives.write('>%s|%s|%s\n%s\n'%(cluster_id,sample,seq_name,seq))
            
store_representatives.close()
# Out:
# 3857 failed, probably because longest contig is from water
# 44862 failed, probably because longest contig is from water
# 68543 failed, probably because longest contig is from water

# %%
longestORF=re.compile('[A-Z]+') ## longest ORF is delimited by *

RdRp_motifs=re.compile('GDD|GDN|SDD|ADN') ## RdRp catalytic domain residues

repr_contig_path=os.path.join(base_path,'darkmatter/representative_contigs.fasta') ## path to representative contigs
RdRp_candidates=open(os.path.join(base_path,'darkmatter/RdRp_candidates.fasta'),'w') ## file where contigs likely to be polymerases will be stored
RdRp_candidate_proteins=open(os.path.join(base_path,'darkmatter/RdRp_candidates_prot.fasta'),'w') ## file where proteins likely to be polymerases will be stored

c=0
t=0

for seq in SeqIO.parse(open(repr_contig_path,'r'),format='fasta'): ## iterate over representative contigs
    candidateORFs=[]
    candidateProt=[]
    
    for s,sequence in enumerate([seq.seq,seq.seq.complement()[::-1]]): ## fwd+rev
        for i in range(3): ## reading frames
            
            translation=str(sequence[i:].translate()) ## translate direction+frame
            
            for protein in longestORF.findall(translation): ## find all proteins
#                 if RdRp_motifs.search(protein) and len(protein)>200: ## protein has RdRp-like motif and is longer than 200 amino acids
                if len(protein)>200:
                    candidateORFs.append(sequence) ## add sequence for later
                    candidateProt.append(protein)
                    
    if len(candidateORFs)>0:
        c+=1
        RdRp_candidates.write('>%s\n%s\n'%(seq.id,seq.seq))
        for p in range(len(candidateProt)):
            RdRp_candidate_proteins.write('>%s|%s\n%s\n'%(seq.id,p,candidateProt[p]))
    t+=1
    
RdRp_candidates.close()
RdRp_candidate_proteins.close()

print(c,t,c/t)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/Bio/Seq.py:2715: BiopythonWarning: Partial codon, len(sequence) not a multiple of three. Explicitly trim the sequence or add trailing N before translation. This may become an error in future.
#   BiopythonWarning)
# 18340 82003 0.2236503542553321

# %%
# %%bash
#
# profiledb=/Users/evogytis/Documents/manuscripts/skeeters/data/darkmatter/RdRp_profiles/RdRp_profiles.pssm.txt ## PSSMs of RdRps
# candidates=/Users/evogytis/Documents/manuscripts/skeeters/data/darkmatter/RdRp_candidates_prot.fasta ## proteins to be scanned with PSSMs
#
# out=${candidates/.fasta/.pssm.out}
#
# hmmscan --noali -o $out $profiledb $candidates ## scan away

# %%
from Bio.SearchIO import HmmerIO

hitfile=os.path.join(base_path,'darkmatter/RdRp_candidates_prot.pssm.out')
hits=HmmerIO.Hmmer3TextParser(open(hitfile,'r'))
RdRp_clusters=set()

# count=0
total=0
for query in sorted(hits,key=lambda k: int(k.id.split('|')[0])):
    if len(query.hits)>0:
        cluster_name,sample,contig_name,_=query.id.split('|')
    
        
        families=[hit.id for hit in query.hits]
        print('%s'%('|'.join(query.id.split('|')[:-1])))
        
        if len(clusters[cluster_name])<2:
            print('contig %s does not belong to a cluster'%(contig_name))
        
        for hit in query.hits:
            if hit.evalue<1e-5:
                print('%s: %s'%(hit.id,hit.evalue))
                if cluster_name in clusters:
                    RdRp_clusters.add(cluster_name)
            else:
                print('not significant',hit.id,hit.evalue)
#             print(query.id
        print()
        
    total+=1

count=len(RdRp_clusters)
print(len(RdRp_clusters))
print('%s hits out of %s (no hits: %s; fraction: %s)'%(count,total,total-count,count/total))
# 163 hits out of 21177 (no hits: 21014; fraction: 0.0076970297964773105) ## all proteins >200 aa, unfiltered by catalytic motif
# Out:
# 1|CMS001_039_Ra_S9|NODE_1_length_18277_cov_48.170824
# FlaviRdRp_PF00972_full: 5.9e-27
#
# 2|CMS002_032a_Rb_S166_L004|NODE_1_length_13844_cov_454.512457
# MononegaRdRp_PF00946_full: 1.4e-216
#
# 3|CMS001_039_Ra_S9|NODE_2_length_13816_cov_21.969794
# contig NODE_2_length_13816_cov_21.969794 does not belong to a cluster
# MononegaRdRp_PF00946_full: 6.9e-217
#
# 4|CMS002_053a_Rb_S7_L004|NODE_1_length_13637_cov_31.429499
# MononegaRdRp_PF00946_full: 2e-222
#
# 5|CMS002_017c_Rb_S124_L004|NODE_1_length_12898_cov_39.149754
# MononegaRdRp_PF00946_full: 9.1e-163
#
# 6|CMS001_008_Ra_S3|NODE_1_length_12382_cov_11.752133
# MononegaRdRp_PF00946_full: 6.8e-155
#
# 7|CMS002_020c_Rb_S133_L004|NODE_1_length_12368_cov_173.470507
# MononegaRdRp_PF00946_full: 6.8e-155
#
# 8|CMS002_035a_Rb_S169_L004|NODE_1_length_11789_cov_864.832650
# MononegaRdRp_PF00946_full: 1.3e-264
#
# 9|CMS002_047g_Rb_S200_L004|NODE_1_length_11763_cov_406.947715
# BromoTobamoTogaRdRp_PF00978_full: 6.4e-77
# PicornaRdRp_PF00680_full: 1.3e-07
#
# 11|CMS002_029d_Rb_S162_L004|NODE_1_length_10957_cov_129.744853
# contig NODE_1_length_10957_cov_129.744853 does not belong to a cluster
# BromoTobamoTogaRdRp_PF00978_full: 5.9e-77
# PicornaRdRp_PF00680_full: 1.1e-07
#
# 12|CMS001_029_Ra_S18|NODE_1_length_10946_cov_79.583034
# FlaviRdRp_PF00972_full: 8.6e-181
# PicornaRdRp_PF00680_full: 1.1e-12
#
# 13|CMS002_047h_Rb_S1_L004|NODE_1_length_10922_cov_58.303550
# BromoTobamoTogaRdRp_PF00978_full: 4.1e-84
#
# 15|CMS001_020_Ra_S15|NODE_1_length_10817_cov_49.966667
# contig NODE_1_length_10817_cov_49.966667 does not belong to a cluster
# BromoTobamoTogaRdRp_PF00978_full: 6.3e-77
# PicornaRdRp_PF00680_full: 1.3e-07
#
# 16|CMS001_032_Ra_S7|NODE_1_length_10763_cov_35.536028
# contig NODE_1_length_10763_cov_35.536028 does not belong to a cluster
# FlaviRdRp_PF00972_full: 1.4e-182
# PicornaRdRp_PF00680_full: 1.1e-11
#
# 17|CMS001_048_Ra_S5|NODE_1_length_10707_cov_6.003951
# contig NODE_1_length_10707_cov_6.003951 does not belong to a cluster
# BromoTobamoTogaRdRp_PF00978_full: 6.3e-77
# PicornaRdRp_PF00680_full: 1.2e-07
#
# 18|CMS001_010_Ra_S1|NODE_1_length_10647_cov_8.761022
# BromoTobamoTogaRdRp_PF00978_full: 6.2e-77
# PicornaRdRp_PF00680_full: 1.2e-07
#
# 20|CMS001_018_Ra_S14|NODE_1_length_10371_cov_9.071595
# contig NODE_1_length_10371_cov_9.071595 does not belong to a cluster
# BromoTobamoTogaRdRp_PF00978_full: 6e-77
# PicornaRdRp_PF00680_full: 1.2e-07
#
# 23|CMS001_002_Ra_S1|NODE_3_length_9996_cov_1810.573546
# PicornaRdRp_PF00680_full: 9.1e-97
#
# 24|CMS001_060_Ra_S12|NODE_1_length_9916_cov_285.959955
# contig NODE_1_length_9916_cov_285.959955 does not belong to a cluster
# PicornaRdRp_PF00680_full: 5.7e-93
# not significant LuteoTotiRotaRdRp_PF02123_full 1.1e-05
#
# 25|CMS002_020c_Rb_S133_L004|NODE_2_length_9884_cov_284.199042
# PicornaRdRp_PF00680_full: 1e-93
# LuteoTotiRotaRdRp_PF02123_full: 5.4e-06
#
# 27|CMS002_038a_Rb_S172_L004|NODE_2_length_9783_cov_30.124253
# contig NODE_2_length_9783_cov_30.124253 does not belong to a cluster
# PicornaRdRp_PF00680_full: 1.9e-98
#
# 28|CMS002_034a_Rb_S168_L004|NODE_1_length_9781_cov_13.772156
# PicornaRdRp_PF00680_full: 6.1e-97
#
# 29|CMS001_051_Ra_S8|NODE_1_length_9777_cov_11.106392
# contig NODE_1_length_9777_cov_11.106392 does not belong to a cluster
# PicornaRdRp_PF00680_full: 1.5e-98
#
# 30|CMS002_037a_Rb_S171_L004|NODE_1_length_9379_cov_122.411954
# contig NODE_1_length_9379_cov_122.411954 does not belong to a cluster
# MononegaRdRp_PF00946_full: 6e-190
#
# 32|CMS001_031_Ra_S19|NODE_1_length_9312_cov_34.616892
# contig NODE_1_length_9312_cov_34.616892 does not belong to a cluster
# MononegaRdRp_PF00946_full: 8.9e-190
#
# 39|CMS001_051_Ra_S8|NODE_2_length_7775_cov_34.360223
# LuteoTotiRotaRdRp_PF02123_full: 1.6e-61
# PicornaRdRp_PF00680_full: 3.6e-14
# not significant BromoTobamoTogaRdRp_PF00978_full 6.3e-05
#
# 42|CMS001_057_Ra_S11|NODE_2_length_7695_cov_18.576267
# LuteoTotiRotaRdRp_PF02123_full: 3e-60
# PicornaRdRp_PF00680_full: 1.4e-11
#
# 43|CMS002_053a_Rb_S7_L004|NODE_4_length_7692_cov_11.659619
# LuteoTotiRotaRdRp_PF02123_full: 3.7e-61
# PicornaRdRp_PF00680_full: 1.4e-11
#
# 44|CMS002_035a_Rb_S169_L004|NODE_2_length_7663_cov_235.389929
# BunyaRdRp_PF04196_full: 7.1e-87
# ArenaRdRp_PF06317_full: 3.9e-09
# OrthomyxoRdRp_PF00602_full: 6.2e-09
#
# 45|CMS002_054a_Rb_S8_L004|NODE_1_length_7470_cov_515.249290
# MononegaRdRp_PF00946_full: 9.3e-199
#
# 49|CMS002_029d_Rb_S162_L004|NODE_3_length_7380_cov_3.942352
# LuteoTotiRotaRdRp_PF02123_full: 2.2e-62
# PicornaRdRp_PF00680_full: 2.7e-14
# not significant BromoTobamoTogaRdRp_PF00978_full 0.00014
#
# 50|CMS002_022a_Rb_S137_L004|NODE_2_length_7363_cov_8.020725
# contig NODE_2_length_7363_cov_8.020725 does not belong to a cluster
# BromoTobamoTogaRdRp_PF00978_full: 2.1e-51
#
# 55|CMS002_053a_Rb_S7_L004|NODE_5_length_7168_cov_39.954872
# LuteoTotiRotaRdRp_PF02123_full: 1.2e-64
# PicornaRdRp_PF00680_full: 2.5e-09
# not significant BromoTobamoTogaRdRp_PF00978_full 1.4e-05
#
# 56|CMS002_029c_Rb_S161_L004|NODE_2_length_7155_cov_5.347415
# LuteoTotiRotaRdRp_PF02123_full: 1.3e-68
# PicornaRdRp_PF00680_full: 1.8e-08
# not significant BromoTobamoTogaRdRp_PF00978_full 2.1e-05
#
# 57|CMS002_040a_Rb_S174_L004|NODE_2_length_7146_cov_3.261423
# LuteoTotiRotaRdRp_PF02123_full: 6.5e-68
# PicornaRdRp_PF00680_full: 1.3e-08
# not significant BromoTobamoTogaRdRp_PF00978_full 2.9e-05
#
# 59|CMS002_053a_Rb_S7_L004|NODE_6_length_7067_cov_2259.198283
# PicornaRdRp_PF00680_full: 3.1e-19
# BromoTobamoTogaRdRp_PF00978_full: 6e-17
#
# 60|CMS002_044b_Rb_S179_L004|NODE_1_length_7060_cov_2.221681
# PicornaRdRp_PF00680_full: 5.2e-110
# Partitiviridae_ICTV_Mafft_211216_full: 2.1e-12
# LuteoTotiRotaRdRp_PF02123_full: 3.1e-06
# not significant BromoTobamoTogaRdRp_PF00978_full 1.5e-05
#
# 61|CMS001_040_Ra_S21|NODE_1_length_7059_cov_13.082641
# contig NODE_1_length_7059_cov_13.082641 does not belong to a cluster
# BunyaRdRp_PF04196_full: 3.9e-211
#
# 63|CMS001_013_Ra_S5|NODE_1_length_6965_cov_47.988240
# BunyaRdRp_PF04196_full: 4.4e-147
#
# 70|CMS002_045b_Rb_S184_L004|NODE_1_length_6634_cov_114.513192
# BunyaRdRp_PF04196_full: 3e-52
#
# 76|CMS002_028d_Rb_S157_L004|NODE_2_length_6403_cov_43.049162
# BunyaRdRp_PF04196_full: 2.2e-51
#
# 78|CMS001_038_Ra_S22|NODE_2_length_6269_cov_19.304587
# contig NODE_2_length_6269_cov_19.304587 does not belong to a cluster
# LuteoTotiRotaRdRp_PF02123_full: 8.8e-34
# PicornaRdRp_PF00680_full: 8.1e-16
# Partitiviridae_ICTV_Mafft_211216_full: 1.5e-08
# not significant MitoRdRp_PF05919_full 0.00011
#
# 81|CMS002_017a_Rb_S122_L004|NODE_1_length_6223_cov_33.014156
# LuteoTotiRotaRdRp_PF02123_full: 4.9e-27
# PicornaRdRp_PF00680_full: 2e-18
# Partitiviridae_ICTV_Mafft_211216_full: 3.9e-06
#
# 88|CMS001_022_Ra_S6|NODE_2_length_6047_cov_3.099497
# BromoTobamoTogaRdRp_PF00978_full: 2e-21
# PicornaRdRp_PF00680_full: 9.6e-14
# LuteoTotiRotaRdRp_PF02123_full: 3e-10
#
# 98|CMS001_060_Ra_S12|NODE_4_length_5737_cov_11.181979
# contig NODE_4_length_5737_cov_11.181979 does not belong to a cluster
# LuteoTotiRotaRdRp_PF02123_full: 3.1e-78
# PicornaRdRp_PF00680_full: 9.2e-33
# BromoTobamoTogaRdRp_PF00978_full: 7.1e-09
# not significant FlaviRdRp_PF00972_full 5.4e-05
#
# 128|CMS001_001_Ra_S1|NODE_5_length_5116_cov_2209.828736
# BromoTobamoTogaRdRp_PF00978_full: 2.8e-22
# PicornaRdRp_PF00680_full: 4.2e-16
# LuteoTotiRotaRdRp_PF02123_full: 4.8e-08
#
# 226|CMS001_047_Ra_S4|NODE_2_length_4094_cov_7.237491
# contig NODE_2_length_4094_cov_7.237491 does not belong to a cluster
# MitoRdRp_PF05919_full: 1.8e-08
#
# 246|CMS001_012_Ra_S4|NODE_4_length_4019_cov_14.444698
# contig NODE_4_length_4019_cov_14.444698 does not belong to a cluster
# LuteoTotiRotaRdRp_PF02123_full: 9.3e-06
#
# 253|CMS001_012_Ra_S4|NODE_5_length_3972_cov_22.541463
# contig NODE_5_length_3972_cov_22.541463 does not belong to a cluster
# not significant BromoTobamoTogaRdRp_PF00978_full 3e-05
#
# 296|CMS001_001_Ra_S1|NODE_9_length_3713_cov_129.105611
# Reo_alternative_full: 0.0
# PicornaRdRp_PF00680_full: 5.3e-06
#
# 312|CMS001_025_Ra_S7|NODE_8_length_3666_cov_8.406520
# BromoTobamoTogaRdRp_PF00978_full: 2.9e-25
# PicornaRdRp_PF00680_full: 9.5e-24
# LuteoTotiRotaRdRp_PF02123_full: 1.6e-12
#
# 326|CMS002_022a_Rb_S137_L004|NODE_3_length_3619_cov_89.634670
# LuteoTotiRotaRdRp_PF02123_full: 4.5e-36
#
# 354|CMS001_053_Ra_S8|NODE_2_length_3531_cov_10.029820
# contig NODE_2_length_3531_cov_10.029820 does not belong to a cluster
# LuteoTotiRotaRdRp_PF02123_full: 3.4e-37
#
# 399|CMS001_038_Ra_S22|NODE_4_length_3364_cov_2.638272
# MononegaRdRp_PF00946_full: 5.3e-28
#
# 416|CMS001_026_Ra_S18|NODE_13_length_3331_cov_4.147203
# contig NODE_13_length_3331_cov_4.147203 does not belong to a cluster
# not significant MitoRdRp_PF05919_full 2.8e-05
#
# 458|CMS002_056a_Rb_S9_L004|NODE_4_length_3249_cov_3490.915826
# PicornaRdRp_PF00680_full: 4.3e-43
# LuteoTotiRotaRdRp_PF02123_full: 2.3e-28
#
# 484|CMS001_035_Ra_S20|NODE_10_length_3200_cov_65.512648
# PicornaRdRp_PF00680_full: 2.4e-40
# LuteoTotiRotaRdRp_PF02123_full: 2.4e-15
#
# 493|CMS001_044_Ra_S25|NODE_5_length_3184_cov_44.723206
# MitoRdRp_PF05919_full: 9.9e-18
#
# 499|CMS002_056a_Rb_S9_L004|NODE_5_length_3180_cov_494.778601
# contig NODE_5_length_3180_cov_494.778601 does not belong to a cluster
# PicornaRdRp_PF00680_full: 2.5e-40
# LuteoTotiRotaRdRp_PF02123_full: 2.4e-15
#
# 506|CMS002_019a_Rb_S130_L004|NODE_1_length_3167_cov_3289.574434
# PicornaRdRp_PF00680_full: 4.5e-46
# LuteoTotiRotaRdRp_PF02123_full: 6.4e-28
#
# 509|CMS002_047j_Rb_S3_L004|NODE_5_length_3164_cov_625.481697
# MitoRdRp_PF05919_full: 3.1e-18
#
# 516|CMS001_040_Ra_S21|NODE_5_length_3145_cov_135.722295
# contig NODE_5_length_3145_cov_135.722295 does not belong to a cluster
# MitoRdRp_PF05919_full: 3.1e-18
#
# 531|CMS002_020b_Rb_S132_L004|NODE_4_length_3121_cov_1052.131406
# PicornaRdRp_PF00680_full: 1.1e-41
# LuteoTotiRotaRdRp_PF02123_full: 9.2e-29
# not significant MitoRdRp_PF05919_full 9.1e-05
#
# 561|CMS002_045d_Rb_S186_L004|NODE_2_length_3060_cov_2583.644653
# PicornaRdRp_PF00680_full: 2.9e-44
# LuteoTotiRotaRdRp_PF02123_full: 4.7e-28
#
# 706|CMS002_038a_Rb_S172_L004|NODE_12_length_2836_cov_341.811888
# PicornaRdRp_PF00680_full: 3.2e-41
# LuteoTotiRotaRdRp_PF02123_full: 8e-26
# BromoTobamoTogaRdRp_PF00978_full: 1.5e-06
# not significant Partitiviridae_ICTV_Mafft_211216_full 0.0001
#
# 1124|CMS001_036_Ra_S20|NODE_11_length_2476_cov_1.939558
# contig NODE_11_length_2476_cov_1.939558 does not belong to a cluster
# MononegaRdRp_PF00946_full: 2.7e-59
#
# 1160|CMS001_027_Ra_S16|NODE_3_length_2447_cov_21.006751
# OrthomyxoRdRp_PF00602_full: 1.5e-132
# BunyaRdRp_PF04196_full: 1.5e-10
#
# 1168|CMS002_026a_Rb_S146_L004|NODE_2_length_2442_cov_5.123890
# OrthomyxoRdRp_PF00602_full: 4.1e-129
#
# 1170|CMS002_029c_Rb_S161_L004|NODE_9_length_2441_cov_36.508037
# OrthomyxoRdRp_PF00602_full: 4.1e-122
# BunyaRdRp_PF04196_full: 7.7e-11
#
# 1181|CMS002_017c_Rb_S124_L004|NODE_5_length_2434_cov_22.260501
# OrthomyxoRdRp_PF00602_full: 5.8e-122
# BunyaRdRp_PF04196_full: 1.2e-07
#
# 1249|CMS001_009_Ra_S13|NODE_70_length_2389_cov_1.563149
# contig NODE_70_length_2389_cov_1.563149 does not belong to a cluster
# MitoRdRp_PF05919_full: 7.9e-19
#
# 1399|CMS002_053a_Rb_S7_L004|NODE_134_length_2299_cov_1.260126
# contig NODE_134_length_2299_cov_1.260126 does not belong to a cluster
# MitoRdRp_PF05919_full: 1.3e-22
#
# 1438|CMS002_053a_Rb_S7_L004|NODE_136_length_2278_cov_2.307133
# contig NODE_136_length_2278_cov_2.307133 does not belong to a cluster
# MitoRdRp_PF05919_full: 4e-24
#
# 1479|CMS002_053a_Rb_S7_L004|NODE_141_length_2261_cov_4.574176
# contig NODE_141_length_2261_cov_4.574176 does not belong to a cluster
# MitoRdRp_PF05919_full: 1e-18
#
# 1636|CMS002_021a_Rb_S136_L004|NODE_301_length_2191_cov_563.679754
# Partitiviridae_ICTV_Mafft_211216_full: 7.3e-63
# PicornaRdRp_PF00680_full: 1.7e-55
# LuteoTotiRotaRdRp_PF02123_full: 1.5e-16
# BromoTobamoTogaRdRp_PF00978_full: 2.8e-06
#
# 1715|CMS001_012_Ra_S4|NODE_19_length_2157_cov_2.648077
# contig NODE_19_length_2157_cov_2.648077 does not belong to a cluster
# LuteoTotiRotaRdRp_PF02123_full: 3.9e-54
# PicornaRdRp_PF00680_full: 6.1e-11
# BromoTobamoTogaRdRp_PF00978_full: 7.2e-06
#
# 1780|CMS002_021a_Rb_S136_L004|NODE_323_length_2136_cov_1.284119
# contig NODE_323_length_2136_cov_1.284119 does not belong to a cluster
# not significant BromoTobamoTogaRdRp_PF00978_full 4.3e-05
#
# 2118|CMS002_017d_Rb_S125_L004|NODE_7_length_2017_cov_358.241237
# FlaviRdRp_PF00972_full: 2.3e-154
# PicornaRdRp_PF00680_full: 3.2e-10
# not significant BromoTobamoTogaRdRp_PF00978_full 3.5e-05
#
# 2923|CMS001_005_Ra_S3|NODE_94_length_1823_cov_2.475945
# contig NODE_94_length_1823_cov_2.475945 does not belong to a cluster
# LuteoTotiRotaRdRp_PF02123_full: 3.5e-47
# PicornaRdRp_PF00680_full: 2.6e-11
#
# 3061|CMS002_053a_Rb_S7_L004|NODE_257_length_1795_cov_3.930733
# contig NODE_257_length_1795_cov_3.930733 does not belong to a cluster
# MitoRdRp_PF05919_full: 1.1e-20
#
# 3110|CMS002_026d_Rb_S149_L004|NODE_8_length_1787_cov_26.230409
# Partitiviridae_ICTV_Mafft_211216_full: 2.7e-79
# PicornaRdRp_PF00680_full: 1.3e-59
# LuteoTotiRotaRdRp_PF02123_full: 7.6e-16
# BromoTobamoTogaRdRp_PF00978_full: 6e-08
#
# 3256|CMS002_020a_Rb_S131_L004|NODE_200_length_1765_cov_198.981043
# Partitiviridae_ICTV_Mafft_211216_full: 1.4e-63
# PicornaRdRp_PF00680_full: 2.1e-56
# LuteoTotiRotaRdRp_PF02123_full: 1.1e-16
# BromoTobamoTogaRdRp_PF00978_full: 2.6e-06
#
# 3883|CMS002_053a_Rb_S7_L004|NODE_293_length_1668_cov_1.297297
# contig NODE_293_length_1668_cov_1.297297 does not belong to a cluster
# not significant BromoTobamoTogaRdRp_PF00978_full 0.00011
#
# 4269|CMS002_053a_Rb_S7_L004|NODE_311_length_1619_cov_2.165370
# contig NODE_311_length_1619_cov_2.165370 does not belong to a cluster
# MitoRdRp_PF05919_full: 3.7e-17
#
# 4553|CMS001_038_Ra_S22|NODE_25_length_1583_cov_1.702523
# MononegaRdRp_PF00946_full: 1.4e-106
#
# 5308|CMS001_009_Ra_S13|NODE_344_length_1503_cov_2.269285
# contig NODE_344_length_1503_cov_2.269285 does not belong to a cluster
# LuteoTotiRotaRdRp_PF02123_full: 1e-44
# PicornaRdRp_PF00680_full: 1.3e-11
#
# 6512|CMS002_021a_Rb_S136_L004|NODE_1168_length_1406_cov_2.164786
# LuteoTotiRotaRdRp_PF02123_full: 1.5e-42
# PicornaRdRp_PF00680_full: 4.8e-11
#
# 6823|CMS001_001_Ra_S1|NODE_81_length_1383_cov_1.592649
# contig NODE_81_length_1383_cov_1.592649 does not belong to a cluster
# BunyaRdRp_PF04196_full: 6.8e-15
# not significant ArenaRdRp_PF06317_full 2e-05
#
# 9191|CMS002_053a_Rb_S7_L004|NODE_580_length_1250_cov_4.236999
# contig NODE_580_length_1250_cov_4.236999 does not belong to a cluster
# MitoRdRp_PF05919_full: 3.7e-23
#
# 10146|CMS002_046b_Rb_S192_L004|NODE_38_length_1206_cov_4.790080
# contig NODE_38_length_1206_cov_4.790080 does not belong to a cluster
# MitoRdRp_PF05919_full: 1.2e-18
#
# 11277|CMS002_017d_Rb_S125_L004|NODE_10_length_1161_cov_248.109779
# FlaviRdRp_PF00972_full: 3.6e-22
#
# 12259|CMS001_009_Ra_S13|NODE_835_length_1125_cov_1.704198
# contig NODE_835_length_1125_cov_1.704198 does not belong to a cluster
# LuteoTotiRotaRdRp_PF02123_full: 7.8e-17
#
# 12955|CMS001_025_Ra_S7|NODE_330_length_1102_cov_10.451707
# not significant BromoTobamoTogaRdRp_PF00978_full 0.00012
#
# 14663|CMS002_020a_Rb_S131_L004|NODE_738_length_1054_cov_1.305015
# not significant MitoRdRp_PF05919_full 6.9e-05
#
# 16869|CMS001_060_Ra_S12|NODE_1203_length_1000_cov_4.565547
# not significant BromoTobamoTogaRdRp_PF00978_full 6.9e-05
#
# 17639|CMS002_007a_Rb_S118_L004|NODE_2294_length_983_cov_1.416115
# not significant PicornaRdRp_PF00680_full 7.7e-05
#
# 19507|CMS002_020a_Rb_S131_L004|NODE_961_length_943_cov_2.577367
# not significant OrthomyxoRdRp_PF00602_full 2.2e-05
#
# 19890|CMS001_016_Ra_S6|NODE_503_length_936_cov_1.477299
# contig NODE_503_length_936_cov_1.477299 does not belong to a cluster
# LuteoTotiRotaRdRp_PF02123_full: 4.5e-43
# PicornaRdRp_PF00680_full: 6.8e-11
#
# 22000|CMS001_060_Ra_S12|NODE_1584_length_898_cov_0.742996
# contig NODE_1584_length_898_cov_0.742996 does not belong to a cluster
# MitoRdRp_PF05919_full: 2e-06
#
# 22774|CMS001_009_Ra_S13|NODE_1562_length_885_cov_1.720297
# contig NODE_1562_length_885_cov_1.720297 does not belong to a cluster
# FlaviRdRp_PF00972_full: 3.8e-06
#
# 22872|CMS002_020d_Rb_S134_L004|NODE_164_length_884_cov_1.019827
# contig NODE_164_length_884_cov_1.019827 does not belong to a cluster
# LuteoTotiRotaRdRp_PF02123_full: 2.7e-66
# PicornaRdRp_PF00680_full: 1.2e-14
#
# 23471|CMS002_045a_Rb_S183_L004|NODE_16_length_875_cov_1.358396
# contig NODE_16_length_875_cov_1.358396 does not belong to a cluster
# MononegaRdRp_PF00946_full: 4.2e-35
#
# 28474|CMS002_007a_Rb_S118_L004|NODE_3545_length_805_cov_1.910714
# contig NODE_3545_length_805_cov_1.910714 does not belong to a cluster
# not significant ArenaRdRp_PF06317_full 0.074
#
# 31787|CMS002_023a_Rb_S138_L004|NODE_33_length_768_cov_1.162084
# contig NODE_33_length_768_cov_1.162084 does not belong to a cluster
# not significant ArenaRdRp_PF06317_full 0.15
#
# 32822|CMS002_021a_Rb_S136_L004|NODE_5038_length_757_cov_2.616176
# contig NODE_5038_length_757_cov_2.616176 does not belong to a cluster
# LuteoTotiRotaRdRp_PF02123_full: 4e-24
#
# 33175|CMS002_053a_Rb_S7_L004|NODE_1954_length_754_cov_1.305761
# contig NODE_1954_length_754_cov_1.305761 does not belong to a cluster
# MitoRdRp_PF05919_full: 3.2e-07
# LuteoTotiRotaRdRp_PF02123_full: 6.8e-07
#
# 37171|CMS002_007a_Rb_S118_L004|NODE_4548_length_718_cov_1.023401
# contig NODE_4548_length_718_cov_1.023401 does not belong to a cluster
# OrthomyxoRdRp_PF00602_full: 1.6e-06
#
# 47143|CMS002_053a_Rb_S7_L004|NODE_2754_length_647_cov_1.924561
# contig NODE_2754_length_647_cov_1.924561 does not belong to a cluster
# MitoRdRp_PF05919_full: 2.2e-08
#
# 47173|CMS001_014_Ra_S5|NODE_648_length_646_cov_1.527241
# contig NODE_648_length_646_cov_1.527241 does not belong to a cluster
# not significant PicornaRdRp_PF00680_full 0.00011
#
# 47685|CMS001_028_Ra_S17|NODE_190_length_643_cov_0.816254
# contig NODE_190_length_643_cov_0.816254 does not belong to a cluster
# not significant BirnaRdRp_PF04197_full 0.011
#
# 47830|CMS001_022_Ra_S6|NODE_168_length_642_cov_1.302655
# contig NODE_168_length_642_cov_1.302655 does not belong to a cluster
# BunyaRdRp_PF04196_full: 4.2e-14
#
# 49310|CMS001_005_Ra_S3|NODE_2230_length_633_cov_1.062950
# contig NODE_2230_length_633_cov_1.062950 does not belong to a cluster
# not significant PicornaRdRp_PF00680_full 0.00016
#
# 50240|CMS002_020e_Rb_S135_L004|NODE_830_length_628_cov_1.197822
# contig NODE_830_length_628_cov_1.197822 does not belong to a cluster
# LuteoTotiRotaRdRp_PF02123_full: 3.4e-41
# PicornaRdRp_PF00680_full: 4.3e-12
#
# 99
# 99 hits out of 21177 (no hits: 21078; fraction: 0.004674883127921802)
